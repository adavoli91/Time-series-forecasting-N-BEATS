# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import torch
from sklearn.preprocessing import StandardScaler

# %%
dict_params = {'data': {'len_input': 20, 'horizon_forecast': 5, 'size_train': 0.8, 'size_valid': 0.2},
               'model': {'n_comp_trend': 3, 'n_neur_hidden': 100, 'frac_dropout': 0.2},
               'training': {'batch_size': 128, 'n_epochs': 500, 'patience': 50, 'min_delta_loss_perc': 0.01}}

# %%
class Block(torch.nn.Module):
    def __init__(self, dict_params: dict, component: str):
        '''
        Block of the N-BEATS architecture. The formulae are implemented slightly differently than in the original paper:
        the input data is in the form (batch_size, n_feat, len_input), the matrix multiplications are implemented as
        theta_f*T^T (theta_f*S^T) and the forecast output has dimensions (batch_size, n_feat, horizon_forecast); actually,
        only the first feature of the input is kept, representing the forecast of the time series.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            component: String representing the component to be modelled; it can be either 'trend' or 'seasonality'.
            
        Returns: None
        '''
        super().__init__()
        #
        len_input = dict_params['data']['len_input']
        horizon_forecast = dict_params['data']['horizon_forecast']
        n_comp_trend = dict_params['model']['n_comp_trend']
        n_neur_hidden = dict_params['model']['n_neur_hidden']
        frac_dropout = dict_params['model']['frac_dropout']
        self.component = component
        # hidden layers of the FC stack
        self.dense_hid_1 = torch.nn.Linear(in_features = len_input, out_features = n_neur_hidden)
        self.dense_hid_2 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.dense_hid_3 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.dense_hid_4 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.relu = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p = frac_dropout)
        self.batch_norm_1 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_2 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_3 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_4 = torch.nn.BatchNorm1d(n_neur_hidden)
        # dense layer for producing the theta's
        self.dense_theta_b = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden, bias = False)
        if component == 'trend':
            self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_comp_trend + 1, bias = False)
        if component == 'seasonality':
            self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = 2*int(np.floor(horizon_forecast/2-1)) + 1, bias = False)
        # trend and seasonality matrices
        self.mat_T = np.hstack([(np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast)**p for p in range(n_comp_trend+1)]).astype(np.float32)
        self.mat_S = np.hstack([np.arange(horizon_forecast).reshape(-1, 1)**0] +
                               [np.cos(2*np.pi*i*np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast) for i in
                                range(1, int(np.floor(horizon_forecast/2-1)) + 1)] +
                               [np.sin(2*np.pi*i*np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast) for i in
                                range(1, int(np.floor(horizon_forecast/2-1)) + 1)]).astype(np.float32)
        self.mat_T, self.mat_S = torch.tensor(self.mat_T), torch.tensor(self.mat_S)
        # final layer for backcasting
        self.dense_x_hat = torch.nn.Linear(in_features = n_neur_hidden, out_features = len_input)
        
    def forward(self, x):
        y = self.dense_hid_1(x).transpose(1, 2)
        y = self.batch_norm_1(y).transpose(1, 2)
        y = self.relu(y)
        y = self.dropout(y)
        for i in range(3):
            hidden_layer = [self.dense_hid_2, self.dense_hid_3, self.dense_hid_4][i]
            batch_norm = [self.batch_norm_2, self.batch_norm_3, self.batch_norm_4][i]
            y = hidden_layer(y).transpose(1, 2)
            y = batch_norm(y).transpose(1, 2)
            y = self.relu(y)
            y = self.dropout(y)
        # compute theta's
        theta_b = self.dense_theta_b(y)
        theta_f = self.dense_theta_f(y)
        # compute backcast
        x_hat = self.dense_x_hat(theta_b)
        # compute time series components
        if self.component == 'trend':
            y_hat = torch.matmul(theta_f, self.mat_T.T)[:, :1, :]
        if self.component == 'seasonality':
            y_hat = torch.matmul(theta_f, self.mat_S.T)[:, :1, :]
        #
        return x_hat, y_hat

class Stack(torch.nn.Module):
    def __init__(self, dict_params: dict, component: str):
        '''
        Stack of the N-BEATS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            component: String representing the component to be modelled; it can be either 'trend' or 'seasonality'.
            
        Returns: None
        '''
        super().__init__()
        #
        self.block_1 = Block(dict_params = dict_params, component = component)
        self.block_2 = Block(dict_params = dict_params, component = component)
        self.block_3 = Block(dict_params = dict_params, component = component)
        
    def forward(self, x):
        # first block
        x_hat, y = self.block_1(x)
        x = x - x_hat
        y_hat = y
        # second block
        x_hat, y = self.block_2(x)
        x = x - x_hat
        y_hat += y
        # third block
        x_hat, y = self.block_3(x)
        x = x - x_hat
        y_hat += y
        #
        x_hat = x
        return x_hat, y_hat

class NBeats(torch.nn.Module):
    def __init__(self, dict_params: dict):
        '''
        N-BEATS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            
        Returns: None
        '''
        super().__init__()
        #
        self.stack_trend = Stack(dict_params = dict_params, component = 'trend')
        self.stack_seas = Stack(dict_params = dict_params, component = 'seasonality')
        
    def forward(self, x):
        # trend stack
        x_hat, y_hat_trend = self.stack_trend(x)
        x = x - x_hat
        # seasonality stack
        _, y_hat_seas = self.stack_seas(x)
        #
        return y_hat_trend, y_hat_seas

# %%
def train_test_splitting(df: pd.DataFrame, dict_params: dict) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame):
    '''
    Function to split data in training, validation and test set.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        dict_params: Dictionary containing information about the model architecture.

    Returns:
        df_train: Dataframe corresponding to training set.
        df_valid: Dataframe corresponding to validation set.
        df_test: Dataframe corresponding to test set.
    '''
    df_train = df.iloc[:int(df.shape[0]*dict_params['data']['size_train'])].copy().reset_index(drop = True)
    df_test = df.iloc[int(df.shape[0]*dict_params['data']['size_train']):].reset_index(drop = True).copy().reset_index(drop = True)
    df_valid = df_train.iloc[int(df_train.shape[0]*(1 - dict_params['data']['size_valid'])):].copy().reset_index(drop = True)
    df_train = df_train.iloc[:int(df_train.shape[0]*(1 - dict_params['data']['size_valid']))].copy().reset_index(drop = True)
    # rescale data
    scaler = StandardScaler().fit(df_train[['y']])
    df_train[['y']] = scaler.transform(df_train[['y']])
    df_valid[['y']] = scaler.transform(df_valid[['y']])
    df_test[['y']] = scaler.transform(df_test[['y']])
    #
    return df_train, df_valid, df_test, scaler

# %%
def get_x_y(df: pd.DataFrame, df_future: pd.DataFrame, dict_params: dict, test_set: bool = False,
            horizon_forecast: int = None) -> (torch.tensor, torch.tensor, np.array, np.array):
    '''
    Function obtain a tensor of regressors and one of target series.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        df_future: Same as `df`, but corresponding to its future (e.g., `df_valid` could be the "future" of `df_train`).
        dict_params: Dictionary containing information about the model architecture.
        test_set: Whether `df` is the dataframe corresponding to test set.
        horizon_forecast: Length of the series to be predicted.

    Returns:
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_x: Array containing the dates corresponding to the elements of `x`.
        date_y: Array containing the dates corresponding to the elements of `y`.
    '''
    dict_params = dict_params['data']
    #
    len_input = dict_params['len_input']
    if (horizon_forecast is None) or (horizon_forecast >= len_input):
        horizon_forecast = len_input
    #
    df_present = df.copy()
    if test_set == False:
        df_future = pd.concat((df_present, df_future)).copy().shift(-len_input)
        df_future = df_future.iloc[:df_present.shape[0]].reset_index(drop = True)
    else:
        df_future = df_present.copy().shift(-len_input).dropna()
        df_present = df_present.iloc[:df_future.shape[0]]
    #
    x = np.array([df_present.loc[i: i + len_input - 1,
                                 [col for col in df_present.columns if col != 'date']].values for i in range(df_present.shape[0] - len_input)])
    y = np.array([df_future.loc[i: i + horizon_forecast - 1, ['y']].values for i in range(df_future.shape[0] - horizon_forecast)])
    date_x = np.array([df_present.loc[i: i + len_input - 1, 'date'].values for i in range(df_present.shape[0] - len_input)])
    date_y = np.array([df_future.loc[i: i + horizon_forecast - 1, 'date'].values for i in range(df_future.shape[0] - horizon_forecast)])
    #
    y = y[:x.shape[0]]
    date_y = date_y[:date_x.shape[0]]
    #
    x = torch.tensor(x.astype(np.float32))
    y = torch.tensor(y.astype(np.float32))
    #
    if len(x.shape) == 2:
        x = x.reshape(x.shape[0], 1, -1)
        y = y.reshape(y.shape[0], 1, -1)
        date_x = date_x.reshape(x.shape[0], 1, -1)
        date_y = date_y.reshape(y.shape[0], 1, -1)
    if len(x.shape) == 3:
        x = torch.tensor(np.einsum('btc -> bct', x))
        y = torch.tensor(np.einsum('btc -> bct', y))
        date_x = date_x.reshape(x.shape[0], 1, -1)
        date_y = date_y.reshape(y.shape[0], 1, -1)
    #
    return x, y, date_x, date_y

# %%
class CreateDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        '''
        Class to create a PyTorch dataset.
        
        Args:
            x: Tensor representing regressors.
            y: Tensor representing target time series.
            
        Returns: None.
        '''
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.x.shape[0]
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
class TrainNBeats:
    def __init__(self, model: torch.nn.Module, dict_params: dict, dataloader_train: torch.utils.data.DataLoader, dataloader_valid: torch.utils.data.DataLoader):
        '''
        Class to train the TCN model.
        
        Args:
            model: PyTorch model.
            dict_params: Dictionary containing information about the model architecture.
            dataloader_train: Dataloader containing training data.
            dataloader_valid: Dataloader containing validation data.
            
        Returns: None.
        '''
        self.model = model
        self.dict_params = dict_params
        self.loss_func = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(params = model.parameters())
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer = self.optimizer, factor = 0.5)
        self.dataloader_train = dataloader_train
        self.dataloader_valid = dataloader_valid

    def _model_on_batch(self, batch: tuple, training: bool, loss_epoch: float) -> float:
        '''
        Function to perform training on a single batch of data.
        
        Args:
            batch: Batch of data to use for training/evaluation.
            training: Whether to perform training (if not, evaluation is understood).
            loss_epoch: Loss of the current epoch.
            
        Returns:
            loss: Value of the loss function.
        '''
        if training == True:
            self.optimizer.zero_grad()
        #
        x, y_true = batch
        x = x.to('cpu')
        y_true = y_true.to('cpu')
        y_hat_trend, y_hat_seas = self.model(x)
        y_hat_trend = y_hat_trend.to('cpu')
        y_hat_seas = y_hat_seas.to('cpu')
        #
        loss = self.loss_func(y_hat_trend, y_true)
        #
        if training == True:
            loss.backward()
            self.optimizer.step()
        #
        return loss.item()

    def _train(self) -> float:
        '''
        Function to train the TCN model on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the training loss function per batch.
        '''
        self.model.train()
        loss_epoch = 0
        for batch in self.dataloader_train:
            loss_epoch += self._model_on_batch(batch = batch, training = True, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_train)

    def _eval(self) -> float:
        '''
        Function to evaluate the TCN model on the validation set on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the validation loss function per batch.
        '''
        self.model.eval()
        loss_epoch = 0
        with torch.no_grad():
            for batch in self.dataloader_valid:
                loss_epoch += self._model_on_batch(batch = batch, training = False, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_valid)

    def train_model(self) -> (torch.nn.Module, list, list):
        '''
        Function to train the TCN model.
        
        Args: None.
            
        Returns:
            model: Trained N-BEATS model.
            list_loss_train: List of training loss function across the epochs.
            list_loss_valid: List of validation loss function across the epochs.
        '''
        dict_params = self.dict_params
        n_epochs = dict_params['training']['n_epochs']
        list_loss_train, list_loss_valid = [], []
        counter_patience = 0
        for epoch in range(1, n_epochs + 1):
            loss_train = self._train()
            loss_valid = self._eval()
            #
            if (len(list_loss_valid) > 0) and (loss_valid >= np.min(list_loss_valid)*(1 - dict_params['training']['min_delta_loss_perc'])):
                counter_patience += 1
            if (len(list_loss_valid) == 0) or ((len(list_loss_valid) > 0) and (loss_valid < np.min(list_loss_valid))):
                counter_patience = 0
                torch.save(self.model.state_dict(), '../data/artifacts/weights.p')
            if counter_patience >= dict_params['training']['patience']:
                print(f'Training stopped at epoch {epoch}. Restoring weights from epoch {np.argmin(list_loss_valid) + 1}.')
                self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
                break
            #
            print(f'Epoch {epoch}: training loss = {loss_train:.4f}, validation loss = {loss_valid:.4f}, patience counter = {counter_patience}.')
            self.scheduler.step(loss_valid)
            #
            list_loss_train.append(loss_train)
            list_loss_valid.append(loss_valid)
        if epoch == n_epochs:
            self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
        return self.model, list_loss_train, list_loss_valid

# %%
def get_y_true_y_hat(model: torch.nn.Module, x: torch.tensor, y: torch.tensor, date_y: np.array,
                     scaler: sklearn.preprocessing.StandardScaler) -> (np.array, np.array, np.array):
    '''
    Function to get the real time series and its prediction.
    
    Args:
        model: Trained TCN model.
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_y: Array containing the dates corresponding to the elements of `y`.
        scaler: Scaled used to rescale data.
        
    Returns:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
    '''
    list_date = []
    y_true = []
    y_hat_trend, y_hat_seas = [], []
    preds_trend, pred_seas = model(x)
    for i in range(np.unique(date_y).shape[0]):
        date = np.unique(date_y)[i]
        list_date.append(date)
        idx = np.where(date_y == date)
        y_true.append(y.numpy()[idx].mean())
        y_hat_trend.append(preds_trend.detach().numpy()[idx].mean())
        y_hat_seas.append(pred_seas.detach().numpy()[idx].mean())
    y_true = np.array(y_true)
    y_hat_trend = np.array(y_hat_trend)
    y_hat_seas = np.array(y_hat_seas)
    # scale back
    y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).ravel()
    y_hat_trend = scaler.inverse_transform(y_hat_trend.reshape(-1, 1)).ravel()
    y_hat_seas = scaler.inverse_transform(y_hat_seas.reshape(-1, 1)).ravel()
    #
    return y_true, y_hat_trend, y_hat_seas

# %%
def compute_mape(y_true: np.array, y_hat_trend: np.array, y_hat_seas: np.array, scaler: sklearn.preprocessing.StandardScaler) -> float:
    '''
    Function to compute the MAPE.
    
    Args:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
        scaler: Scaled used to rescale data.
        
    Returns:
        mape: MAPE computed from `y_true` and `y_hat`.
    '''
    y_hat = y_hat_trend + y_hat_seas - scaler.mean_
    mape = np.mean(abs(y_true[y_true > 0] - y_hat[y_true > 0])/y_true[y_true > 0])
    return mape

# %%
df = pd.read_csv('../data/raw/train.csv', parse_dates = ['date'], index_col = 'id')
df = df.groupby(['date', 'family']).agg({'sales': 'sum'}).reset_index()
# add all dates
df_temp = []
for family in df['family'].unique():
    df_temp.append(pd.DataFrame({'date': pd.date_range(df['date'].min(), df['date'].max())}).merge(df[df['family'] == family],
                                                                                                on = 'date', how = 'left'))
    df_temp[-1]['family'] = family
    df_temp[-1]['sales'] = df_temp[-1]['sales'].ffill()
df = pd.concat(df_temp).reset_index(drop = True)
del df_temp
df = df.rename(columns = {'sales': 'y'})
# perform train-test splitting
df_train, df_valid, df_test, scaler = train_test_splitting(df = df[df['family'] == 'AUTOMOTIVE'].reset_index(drop = True).drop('family', axis = 1),
                                                        dict_params = dict_params)
#
horizon_forecast = dict_params['data']['horizon_forecast']
# training set data
x_train, y_train, date_x_train, date_y_train = get_x_y(df = df_train, df_future = df_valid, dict_params = dict_params,
                                                    test_set = False, horizon_forecast = horizon_forecast)
# validation set data
x_valid, y_valid, date_x_valid, date_y_valid = get_x_y(df = df_valid, df_future = df_test, dict_params = dict_params,
                                                    test_set = False, horizon_forecast = horizon_forecast)
# test set data
x_test, y_test, date_x_test, date_y_test = get_x_y(df = df_test, df_future = None, dict_params = dict_params, test_set = True,
                                                horizon_forecast = horizon_forecast)
# create datasets and dataloader
dataset_train = CreateDataset(x = x_train, y = y_train)
dataset_valid = CreateDataset(x = x_valid, y = y_valid)
dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size = dict_params['training']['batch_size'], shuffle = True)
dataloader_valid = torch.utils.data.DataLoader(dataset_valid, batch_size = dict_params['training']['batch_size'], shuffle = False)
# train model
model = NBeats(dict_params = dict_params)
model, list_loss_train, list_loss_valid = TrainNBeats(model = model, dict_params = dict_params, dataloader_train = dataloader_train, dataloader_valid = dataloader_train).train_model()
# evaluate results
model = NBeats(dict_params = dict_params)
model.load_state_dict(torch.load('../data/artifacts/weights.p'))
model.eval()
# get time series and the corresponding predictions
y_true_train, y_hat_trend_train, y_hat_seas_train = get_y_true_y_hat(model = model, x = x_train, y = y_train, date_y = date_y_train, scaler = scaler)
y_true_valid, y_hat_trend_valid, y_hat_seas_valid = get_y_true_y_hat(model = model, x = x_valid, y = y_valid, date_y = date_y_valid, scaler = scaler)
y_true_test, y_hat_trend_test, y_hat_seas_test = get_y_true_y_hat(model = model, x = x_test, y = y_test, date_y = date_y_test, scaler = scaler)
# compute mape on training, validation and test set
mape_train = compute_mape(y_true = y_true_train, y_hat_trend = y_hat_trend_train, y_hat_seas = y_hat_seas_train, scaler = scaler)
mape_valid = compute_mape(y_true = y_true_valid, y_hat_trend = y_hat_trend_valid, y_hat_seas = y_hat_seas_valid, scaler = scaler)
mape_test = compute_mape(y_true = y_true_test, y_hat_trend = y_hat_trend_test, y_hat_seas = y_hat_seas_test, scaler = scaler)
#
plt.figure(figsize = [10, 6])
plt.plot(np.unique(date_y_test), y_true_test, label = 'True', color = 'r')
plt.plot(np.unique(date_y_test), y_hat_trend_test + y_hat_seas_test - scaler.mean_, label = 'Predicted', color = 'b')
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.xticks(rotation = 45)
plt.legend()
plt.savefig('../docs/figures_for_readme/result', bbox_inches = 'tight')
# Out:
# Epoch 1: training loss = 1.3666, validation loss = 0.9035, patience counter = 0.
# Epoch 2: training loss = 0.9329, validation loss = 0.7613, patience counter = 0.
# Epoch 3: training loss = 0.8674, validation loss = 0.5884, patience counter = 0.
# Epoch 4: training loss = 0.7793, validation loss = 0.5286, patience counter = 0.
# Epoch 5: training loss = 0.7106, validation loss = 0.5037, patience counter = 0.
# Epoch 6: training loss = 0.6822, validation loss = 0.4775, patience counter = 0.
# Epoch 7: training loss = 0.6352, validation loss = 0.4496, patience counter = 0.
# Epoch 8: training loss = 0.6057, validation loss = 0.4526, patience counter = 1.
# Epoch 9: training loss = 0.5660, validation loss = 0.4279, patience counter = 0.
# Epoch 10: training loss = 0.5836, validation loss = 0.4121, patience counter = 0.
# Epoch 11: training loss = 0.5484, validation loss = 0.4097, patience counter = 0.
# Epoch 12: training loss = 0.5225, validation loss = 0.4102, patience counter = 1.
# Epoch 13: training loss = 0.5009, validation loss = 0.3989, patience counter = 0.
# Epoch 14: training loss = 0.5113, validation loss = 0.4056, patience counter = 1.
# Epoch 15: training loss = 0.4761, validation loss = 0.3930, patience counter = 0.
# Epoch 16: training loss = 0.4786, validation loss = 0.3793, patience counter = 0.
# Epoch 17: training loss = 0.4667, validation loss = 0.3740, patience counter = 0.
# Epoch 18: training loss = 0.4687, validation loss = 0.3677, patience counter = 0.
# Epoch 19: training loss = 0.4332, validation loss = 0.3599, patience counter = 0.
# Epoch 20: training loss = 0.4373, validation loss = 0.3661, patience counter = 1.
# Epoch 21: training loss = 0.4355, validation loss = 0.3685, patience counter = 2.
# Epoch 22: training loss = 0.4416, validation loss = 0.3731, patience counter = 3.
# Epoch 23: training loss = 0.4213, validation loss = 0.3655, patience counter = 4.
# Epoch 24: training loss = 0.4427, validation loss = 0.3682, patience counter = 5.
# Epoch 25: training loss = 0.4272, validation loss = 0.3501, patience counter = 0.
# Epoch 26: training loss = 0.4246, validation loss = 0.3507, patience counter = 1.
# Epoch 27: training loss = 0.4176, validation loss = 0.3569, patience counter = 2.
# Epoch 28: training loss = 0.4225, validation loss = 0.3467, patience counter = 0.
# Epoch 29: training loss = 0.4113, validation loss = 0.3546, patience counter = 1.
# Epoch 30: training loss = 0.4331, validation loss = 0.3581, patience counter = 2.
# Epoch 31: training loss = 0.4301, validation loss = 0.3566, patience counter = 3.
# Epoch 32: training loss = 0.4101, validation loss = 0.3559, patience counter = 4.
# Epoch 33: training loss = 0.4120, validation loss = 0.3670, patience counter = 5.
# Epoch 34: training loss = 0.4070, validation loss = 0.3557, patience counter = 6.
# Epoch 35: training loss = 0.4103, validation loss = 0.3481, patience counter = 7.
# Epoch 36: training loss = 0.4024, validation loss = 0.3439, patience counter = 0.
# Epoch 37: training loss = 0.4143, validation loss = 0.3408, patience counter = 0.
# Epoch 38: training loss = 0.4006, validation loss = 0.3477, patience counter = 1.
# Epoch 39: training loss = 0.4231, validation loss = 0.3528, patience counter = 2.
# Epoch 40: training loss = 0.4039, validation loss = 0.3504, patience counter = 3.
# Epoch 41: training loss = 0.4010, validation loss = 0.3439, patience counter = 4.
# Epoch 42: training loss = 0.4247, validation loss = 0.3559, patience counter = 5.
# Epoch 43: training loss = 0.4072, validation loss = 0.3426, patience counter = 6.
# Epoch 44: training loss = 0.3999, validation loss = 0.3408, patience counter = 7.
# Epoch 45: training loss = 0.3941, validation loss = 0.3430, patience counter = 8.
# Epoch 46: training loss = 0.4027, validation loss = 0.3471, patience counter = 9.
# Epoch 47: training loss = 0.3999, validation loss = 0.3515, patience counter = 10.
# Epoch 48: training loss = 0.3950, validation loss = 0.3388, patience counter = 0.
# Epoch 49: training loss = 0.3914, validation loss = 0.3337, patience counter = 0.
# Epoch 50: training loss = 0.3979, validation loss = 0.3475, patience counter = 1.
# Epoch 51: training loss = 0.3938, validation loss = 0.3291, patience counter = 0.
# Epoch 52: training loss = 0.4040, validation loss = 0.3415, patience counter = 1.
# Epoch 53: training loss = 0.4000, validation loss = 0.3374, patience counter = 2.
# Epoch 54: training loss = 0.3870, validation loss = 0.3448, patience counter = 3.
# Epoch 55: training loss = 0.3916, validation loss = 0.3431, patience counter = 4.
# Epoch 56: training loss = 0.3865, validation loss = 0.3324, patience counter = 5.
# Epoch 57: training loss = 0.3881, validation loss = 0.3318, patience counter = 6.
# Epoch 58: training loss = 0.3868, validation loss = 0.3353, patience counter = 7.
# Epoch 59: training loss = 0.3883, validation loss = 0.3366, patience counter = 8.
# Epoch 60: training loss = 0.3885, validation loss = 0.3273, patience counter = 0.
# Epoch 61: training loss = 0.3960, validation loss = 0.3260, patience counter = 0.
# Epoch 62: training loss = 0.3940, validation loss = 0.3246, patience counter = 0.
# Epoch 63: training loss = 0.4018, validation loss = 0.3442, patience counter = 1.
# Epoch 64: training loss = 0.3796, validation loss = 0.3409, patience counter = 2.
# Epoch 65: training loss = 0.3772, validation loss = 0.3288, patience counter = 3.
# Epoch 66: training loss = 0.3780, validation loss = 0.3371, patience counter = 4.
# Epoch 67: training loss = 0.3911, validation loss = 0.3278, patience counter = 5.
# Epoch 68: training loss = 0.3899, validation loss = 0.3392, patience counter = 6.
# Epoch 69: training loss = 0.3845, validation loss = 0.3437, patience counter = 7.
# Epoch 70: training loss = 0.3845, validation loss = 0.3341, patience counter = 8.
# Epoch 71: training loss = 0.3698, validation loss = 0.3193, patience counter = 0.
# Epoch 72: training loss = 0.3802, validation loss = 0.3273, patience counter = 1.
# Epoch 73: training loss = 0.3913, validation loss = 0.3259, patience counter = 2.
# Epoch 74: training loss = 0.3703, validation loss = 0.3263, patience counter = 3.
# Epoch 75: training loss = 0.3793, validation loss = 0.3234, patience counter = 4.
# Epoch 76: training loss = 0.3709, validation loss = 0.3201, patience counter = 5.
# Epoch 77: training loss = 0.3672, validation loss = 0.3207, patience counter = 6.
# Epoch 78: training loss = 0.3774, validation loss = 0.3178, patience counter = 0.
# Epoch 79: training loss = 0.3647, validation loss = 0.3211, patience counter = 1.
# Epoch 80: training loss = 0.3873, validation loss = 0.3120, patience counter = 0.
# Epoch 81: training loss = 0.3659, validation loss = 0.3162, patience counter = 1.
# Epoch 82: training loss = 0.3609, validation loss = 0.3188, patience counter = 2.
# Epoch 83: training loss = 0.3657, validation loss = 0.3112, patience counter = 0.
# Epoch 84: training loss = 0.3721, validation loss = 0.3158, patience counter = 1.
# Epoch 85: training loss = 0.3593, validation loss = 0.3145, patience counter = 2.
# Epoch 86: training loss = 0.3571, validation loss = 0.3058, patience counter = 0.
# Epoch 87: training loss = 0.3597, validation loss = 0.3100, patience counter = 1.
# Epoch 88: training loss = 0.3708, validation loss = 0.3124, patience counter = 2.
# Epoch 89: training loss = 0.3575, validation loss = 0.3091, patience counter = 3.
# Epoch 90: training loss = 0.3569, validation loss = 0.3208, patience counter = 4.
# Epoch 91: training loss = 0.3680, validation loss = 0.3105, patience counter = 5.
# Epoch 92: training loss = 0.3572, validation loss = 0.3059, patience counter = 6.
# Epoch 93: training loss = 0.3460, validation loss = 0.3049, patience counter = 0.
# Epoch 94: training loss = 0.3615, validation loss = 0.3037, patience counter = 0.
# Epoch 95: training loss = 0.3572, validation loss = 0.3061, patience counter = 1.
# Epoch 96: training loss = 0.3581, validation loss = 0.3027, patience counter = 0.
# Epoch 97: training loss = 0.3642, validation loss = 0.3062, patience counter = 1.
# Epoch 98: training loss = 0.3577, validation loss = 0.3058, patience counter = 2.
# Epoch 99: training loss = 0.3445, validation loss = 0.3182, patience counter = 3.
# Epoch 100: training loss = 0.3513, validation loss = 0.3020, patience counter = 0.
# Epoch 101: training loss = 0.3467, validation loss = 0.3055, patience counter = 1.
# Epoch 102: training loss = 0.3635, validation loss = 0.3066, patience counter = 2.
# Epoch 103: training loss = 0.3464, validation loss = 0.3005, patience counter = 0.
# Epoch 104: training loss = 0.3573, validation loss = 0.3166, patience counter = 1.
# Epoch 105: training loss = 0.3505, validation loss = 0.3074, patience counter = 2.
# Epoch 106: training loss = 0.3588, validation loss = 0.3019, patience counter = 3.
# Epoch 107: training loss = 0.3581, validation loss = 0.3006, patience counter = 4.
# Epoch 108: training loss = 0.3587, validation loss = 0.3173, patience counter = 5.
# Epoch 109: training loss = 0.3625, validation loss = 0.2913, patience counter = 0.
# Epoch 110: training loss = 0.3495, validation loss = 0.2976, patience counter = 1.
# Epoch 111: training loss = 0.3386, validation loss = 0.3054, patience counter = 2.
# Epoch 112: training loss = 0.3534, validation loss = 0.3090, patience counter = 3.
# Epoch 113: training loss = 0.3453, validation loss = 0.2977, patience counter = 4.
# Epoch 114: training loss = 0.3522, validation loss = 0.2942, patience counter = 5.
# Epoch 115: training loss = 0.3465, validation loss = 0.3134, patience counter = 6.
# Epoch 116: training loss = 0.3707, validation loss = 0.3051, patience counter = 7.
# Epoch 117: training loss = 0.3519, validation loss = 0.2918, patience counter = 8.
# Epoch 118: training loss = 0.3511, validation loss = 0.2982, patience counter = 9.
# Epoch 119: training loss = 0.3444, validation loss = 0.2989, patience counter = 10.
# Epoch 120: training loss = 0.3427, validation loss = 0.2894, patience counter = 0.
# Epoch 121: training loss = 0.3572, validation loss = 0.3053, patience counter = 1.
# Epoch 122: training loss = 0.3511, validation loss = 0.2916, patience counter = 2.
# Epoch 123: training loss = 0.3512, validation loss = 0.2917, patience counter = 3.
# Epoch 124: training loss = 0.3415, validation loss = 0.2911, patience counter = 4.
# Epoch 125: training loss = 0.3601, validation loss = 0.2921, patience counter = 5.
# Epoch 126: training loss = 0.3490, validation loss = 0.2893, patience counter = 0.
# Epoch 127: training loss = 0.3464, validation loss = 0.2833, patience counter = 0.
# Epoch 128: training loss = 0.3460, validation loss = 0.2895, patience counter = 1.
# Epoch 129: training loss = 0.3434, validation loss = 0.2839, patience counter = 2.
# Epoch 130: training loss = 0.3533, validation loss = 0.2921, patience counter = 3.
# Epoch 131: training loss = 0.3494, validation loss = 0.2879, patience counter = 4.
# Epoch 132: training loss = 0.3371, validation loss = 0.2878, patience counter = 5.
# Epoch 133: training loss = 0.3323, validation loss = 0.2927, patience counter = 6.
# Epoch 134: training loss = 0.3540, validation loss = 0.3173, patience counter = 7.
# Epoch 135: training loss = 0.3330, validation loss = 0.2873, patience counter = 8.
# Epoch 136: training loss = 0.3459, validation loss = 0.2921, patience counter = 9.
# Epoch 137: training loss = 0.3366, validation loss = 0.2776, patience counter = 0.
# Epoch 138: training loss = 0.3396, validation loss = 0.2931, patience counter = 1.
# Epoch 139: training loss = 0.3287, validation loss = 0.2924, patience counter = 2.
# Epoch 140: training loss = 0.3316, validation loss = 0.2884, patience counter = 3.
# Epoch 141: training loss = 0.3436, validation loss = 0.2803, patience counter = 4.
# Epoch 142: training loss = 0.3417, validation loss = 0.2932, patience counter = 5.
# Epoch 143: training loss = 0.3353, validation loss = 0.2781, patience counter = 6.
# Epoch 144: training loss = 0.3346, validation loss = 0.2846, patience counter = 7.
# Epoch 145: training loss = 0.3371, validation loss = 0.2795, patience counter = 8.
# Epoch 146: training loss = 0.3224, validation loss = 0.2836, patience counter = 9.
# Epoch 147: training loss = 0.3372, validation loss = 0.2789, patience counter = 10.
# Epoch 148: training loss = 0.3340, validation loss = 0.2789, patience counter = 11.
# Epoch 149: training loss = 0.3266, validation loss = 0.2773, patience counter = 0.
# Epoch 150: training loss = 0.3334, validation loss = 0.2734, patience counter = 0.
# Epoch 151: training loss = 0.3220, validation loss = 0.2728, patience counter = 0.
# Epoch 152: training loss = 0.3285, validation loss = 0.2697, patience counter = 0.
# Epoch 153: training loss = 0.3212, validation loss = 0.2752, patience counter = 1.
# Epoch 154: training loss = 0.3183, validation loss = 0.2679, patience counter = 0.
# Epoch 155: training loss = 0.3350, validation loss = 0.2754, patience counter = 1.
# Epoch 156: training loss = 0.3328, validation loss = 0.2673, patience counter = 0.
# Epoch 157: training loss = 0.3201, validation loss = 0.2798, patience counter = 1.
# Epoch 158: training loss = 0.3210, validation loss = 0.2649, patience counter = 0.
# Epoch 159: training loss = 0.3288, validation loss = 0.2769, patience counter = 1.
# Epoch 160: training loss = 0.3224, validation loss = 0.2707, patience counter = 2.
# Epoch 161: training loss = 0.3257, validation loss = 0.2749, patience counter = 3.
# Epoch 162: training loss = 0.3129, validation loss = 0.2671, patience counter = 4.
# Epoch 163: training loss = 0.3228, validation loss = 0.2708, patience counter = 5.
# Epoch 164: training loss = 0.3331, validation loss = 0.2677, patience counter = 6.
# Epoch 165: training loss = 0.3171, validation loss = 0.2693, patience counter = 7.
# Epoch 166: training loss = 0.3281, validation loss = 0.2729, patience counter = 8.
# Epoch 167: training loss = 0.3152, validation loss = 0.2685, patience counter = 9.
# Epoch 168: training loss = 0.3258, validation loss = 0.2700, patience counter = 10.
# Epoch 169: training loss = 0.3205, validation loss = 0.2691, patience counter = 11.
# Epoch 170: training loss = 0.3267, validation loss = 0.2734, patience counter = 12.
# Epoch 171: training loss = 0.3287, validation loss = 0.2672, patience counter = 13.
# Epoch 172: training loss = 0.3214, validation loss = 0.2741, patience counter = 14.
# Epoch 173: training loss = 0.3103, validation loss = 0.2645, patience counter = 0.
# Epoch 174: training loss = 0.3116, validation loss = 0.2716, patience counter = 1.
# Epoch 175: training loss = 0.3204, validation loss = 0.2671, patience counter = 2.
# Epoch 176: training loss = 0.3191, validation loss = 0.2737, patience counter = 3.
# Epoch 177: training loss = 0.3221, validation loss = 0.2629, patience counter = 0.
# Epoch 178: training loss = 0.3191, validation loss = 0.2688, patience counter = 1.
# Epoch 179: training loss = 0.3107, validation loss = 0.2600, patience counter = 0.
# Epoch 180: training loss = 0.3109, validation loss = 0.2615, patience counter = 1.
# Epoch 181: training loss = 0.3073, validation loss = 0.2587, patience counter = 0.
# Epoch 182: training loss = 0.3140, validation loss = 0.2601, patience counter = 1.
# Epoch 183: training loss = 0.3127, validation loss = 0.2664, patience counter = 2.
# Epoch 184: training loss = 0.3247, validation loss = 0.2627, patience counter = 3.
# Epoch 185: training loss = 0.3101, validation loss = 0.2660, patience counter = 4.
# Epoch 186: training loss = 0.3180, validation loss = 0.2562, patience counter = 0.
# Epoch 187: training loss = 0.3083, validation loss = 0.2640, patience counter = 1.
# Epoch 188: training loss = 0.3099, validation loss = 0.2649, patience counter = 2.
# Epoch 189: training loss = 0.3212, validation loss = 0.2622, patience counter = 3.
# Epoch 190: training loss = 0.3142, validation loss = 0.2626, patience counter = 4.
# Epoch 191: training loss = 0.3071, validation loss = 0.2614, patience counter = 5.
# Epoch 192: training loss = 0.3113, validation loss = 0.2648, patience counter = 6.
# Epoch 193: training loss = 0.3109, validation loss = 0.2578, patience counter = 7.
# Epoch 194: training loss = 0.3215, validation loss = 0.2614, patience counter = 8.
# Epoch 195: training loss = 0.3129, validation loss = 0.2607, patience counter = 9.
# Epoch 196: training loss = 0.3088, validation loss = 0.2562, patience counter = 10.
# Epoch 197: training loss = 0.3095, validation loss = 0.2566, patience counter = 11.
# Epoch 198: training loss = 0.3149, validation loss = 0.2545, patience counter = 0.
# Epoch 199: training loss = 0.3071, validation loss = 0.2629, patience counter = 1.
# Epoch 200: training loss = 0.3052, validation loss = 0.2530, patience counter = 0.
# Epoch 201: training loss = 0.3104, validation loss = 0.2558, patience counter = 1.
# Epoch 202: training loss = 0.3112, validation loss = 0.2538, patience counter = 2.
# Epoch 203: training loss = 0.3108, validation loss = 0.2714, patience counter = 3.
# Epoch 204: training loss = 0.3150, validation loss = 0.2625, patience counter = 4.
# Epoch 205: training loss = 0.3109, validation loss = 0.2589, patience counter = 5.
# Epoch 206: training loss = 0.3147, validation loss = 0.2622, patience counter = 6.
# Epoch 207: training loss = 0.2970, validation loss = 0.2561, patience counter = 7.
# Epoch 208: training loss = 0.3108, validation loss = 0.2537, patience counter = 8.
# Epoch 209: training loss = 0.3145, validation loss = 0.2619, patience counter = 9.
# Epoch 210: training loss = 0.3248, validation loss = 0.2513, patience counter = 0.
# Epoch 211: training loss = 0.3077, validation loss = 0.2590, patience counter = 1.
# Epoch 212: training loss = 0.3189, validation loss = 0.2604, patience counter = 2.
# Epoch 213: training loss = 0.2956, validation loss = 0.2627, patience counter = 3.
# Epoch 214: training loss = 0.3064, validation loss = 0.2637, patience counter = 4.
# Epoch 215: training loss = 0.3072, validation loss = 0.2536, patience counter = 5.
# Epoch 216: training loss = 0.3175, validation loss = 0.2572, patience counter = 6.
# Epoch 217: training loss = 0.3117, validation loss = 0.2599, patience counter = 7.
# Epoch 218: training loss = 0.3100, validation loss = 0.2602, patience counter = 8.
# Epoch 219: training loss = 0.3012, validation loss = 0.2545, patience counter = 9.
# Epoch 220: training loss = 0.3038, validation loss = 0.2537, patience counter = 10.
# Epoch 221: training loss = 0.3038, validation loss = 0.2539, patience counter = 11.
# Epoch 222: training loss = 0.3098, validation loss = 0.2524, patience counter = 12.
# Epoch 223: training loss = 0.3042, validation loss = 0.2564, patience counter = 13.
# Epoch 224: training loss = 0.3120, validation loss = 0.2539, patience counter = 14.
# Epoch 225: training loss = 0.3100, validation loss = 0.2529, patience counter = 15.
# Epoch 226: training loss = 0.3006, validation loss = 0.2566, patience counter = 16.
# Epoch 227: training loss = 0.3012, validation loss = 0.2517, patience counter = 17.
# Epoch 228: training loss = 0.3089, validation loss = 0.2518, patience counter = 18.
# Epoch 229: training loss = 0.3124, validation loss = 0.2537, patience counter = 19.
# Epoch 230: training loss = 0.3054, validation loss = 0.2549, patience counter = 20.
# Epoch 231: training loss = 0.3040, validation loss = 0.2542, patience counter = 21.
# Epoch 232: training loss = 0.3045, validation loss = 0.2529, patience counter = 22.
# Epoch 233: training loss = 0.3144, validation loss = 0.2563, patience counter = 23.
# Epoch 234: training loss = 0.3100, validation loss = 0.2553, patience counter = 24.
# Epoch 235: training loss = 0.3036, validation loss = 0.2530, patience counter = 25.
# Epoch 236: training loss = 0.3105, validation loss = 0.2533, patience counter = 26.
# Epoch 237: training loss = 0.3034, validation loss = 0.2583, patience counter = 27.
# Epoch 238: training loss = 0.3106, validation loss = 0.2569, patience counter = 28.
# Epoch 239: training loss = 0.3013, validation loss = 0.2541, patience counter = 29.
# Epoch 240: training loss = 0.3261, validation loss = 0.2561, patience counter = 30.
# Epoch 241: training loss = 0.3055, validation loss = 0.2504, patience counter = 0.
# Epoch 242: training loss = 0.3216, validation loss = 0.2599, patience counter = 1.
# Epoch 243: training loss = 0.3048, validation loss = 0.2526, patience counter = 2.
# Epoch 244: training loss = 0.3055, validation loss = 0.2535, patience counter = 3.
# Epoch 245: training loss = 0.3090, validation loss = 0.2580, patience counter = 4.
# Epoch 246: training loss = 0.3050, validation loss = 0.2508, patience counter = 5.
# Epoch 247: training loss = 0.3043, validation loss = 0.2567, patience counter = 6.
# Epoch 248: training loss = 0.3101, validation loss = 0.2534, patience counter = 7.
# Epoch 249: training loss = 0.3045, validation loss = 0.2512, patience counter = 8.
# Epoch 250: training loss = 0.3137, validation loss = 0.2511, patience counter = 9.
# Epoch 251: training loss = 0.3064, validation loss = 0.2577, patience counter = 10.
# Epoch 252: training loss = 0.3138, validation loss = 0.2567, patience counter = 11.
# Epoch 253: training loss = 0.2998, validation loss = 0.2624, patience counter = 12.
# Epoch 254: training loss = 0.3045, validation loss = 0.2537, patience counter = 13.
# Epoch 255: training loss = 0.3090, validation loss = 0.2563, patience counter = 14.
# Epoch 256: training loss = 0.3124, validation loss = 0.2482, patience counter = 0.
# Epoch 257: training loss = 0.3057, validation loss = 0.2510, patience counter = 1.
# Epoch 258: training loss = 0.3067, validation loss = 0.2524, patience counter = 2.
# Epoch 259: training loss = 0.3131, validation loss = 0.2575, patience counter = 3.
# Epoch 260: training loss = 0.3065, validation loss = 0.2592, patience counter = 4.
# Epoch 261: training loss = 0.3056, validation loss = 0.2528, patience counter = 5.
# Epoch 262: training loss = 0.3051, validation loss = 0.2488, patience counter = 6.
# Epoch 263: training loss = 0.3186, validation loss = 0.2502, patience counter = 7.
# Epoch 264: training loss = 0.2980, validation loss = 0.2551, patience counter = 8.
# Epoch 265: training loss = 0.3015, validation loss = 0.2496, patience counter = 9.
# Epoch 266: training loss = 0.3314, validation loss = 0.2589, patience counter = 10.
# Epoch 267: training loss = 0.3111, validation loss = 0.2512, patience counter = 11.
# Epoch 268: training loss = 0.3149, validation loss = 0.2524, patience counter = 12.
# Epoch 269: training loss = 0.3057, validation loss = 0.2528, patience counter = 13.
# Epoch 270: training loss = 0.3015, validation loss = 0.2541, patience counter = 14.
# Epoch 271: training loss = 0.3122, validation loss = 0.2513, patience counter = 15.
# Epoch 272: training loss = 0.3042, validation loss = 0.2578, patience counter = 16.
# Epoch 273: training loss = 0.3068, validation loss = 0.2503, patience counter = 17.
# Epoch 274: training loss = 0.3029, validation loss = 0.2537, patience counter = 18.
# Epoch 275: training loss = 0.3192, validation loss = 0.2629, patience counter = 19.
# Epoch 276: training loss = 0.3075, validation loss = 0.2544, patience counter = 20.
# Epoch 277: training loss = 0.3030, validation loss = 0.2546, patience counter = 21.
# Epoch 278: training loss = 0.3114, validation loss = 0.2589, patience counter = 22.
# Epoch 279: training loss = 0.3050, validation loss = 0.2515, patience counter = 23.
# Epoch 280: training loss = 0.3080, validation loss = 0.2535, patience counter = 24.
# Epoch 281: training loss = 0.3069, validation loss = 0.2609, patience counter = 25.
# Epoch 282: training loss = 0.3047, validation loss = 0.2503, patience counter = 26.
# Epoch 283: training loss = 0.3171, validation loss = 0.2541, patience counter = 27.
# Epoch 284: training loss = 0.3022, validation loss = 0.2534, patience counter = 28.
# Epoch 285: training loss = 0.3062, validation loss = 0.2543, patience counter = 29.
# Epoch 286: training loss = 0.3056, validation loss = 0.2548, patience counter = 30.
# Epoch 287: training loss = 0.3064, validation loss = 0.2613, patience counter = 31.
# Epoch 288: training loss = 0.3055, validation loss = 0.2594, patience counter = 32.
# Epoch 289: training loss = 0.3109, validation loss = 0.2541, patience counter = 33.
# Epoch 290: training loss = 0.3045, validation loss = 0.2554, patience counter = 34.
# Epoch 291: training loss = 0.3090, validation loss = 0.2641, patience counter = 35.
# Epoch 292: training loss = 0.3234, validation loss = 0.2632, patience counter = 36.
# Epoch 293: training loss = 0.3117, validation loss = 0.2552, patience counter = 37.
# Epoch 294: training loss = 0.3048, validation loss = 0.2574, patience counter = 38.
# Epoch 295: training loss = 0.3028, validation loss = 0.2514, patience counter = 39.
# Epoch 296: training loss = 0.3034, validation loss = 0.2506, patience counter = 40.
# Epoch 297: training loss = 0.3024, validation loss = 0.2489, patience counter = 41.
# Epoch 298: training loss = 0.3032, validation loss = 0.2568, patience counter = 42.
# Epoch 299: training loss = 0.3028, validation loss = 0.2507, patience counter = 43.
# Epoch 300: training loss = 0.2960, validation loss = 0.2518, patience counter = 44.
# Epoch 301: training loss = 0.2995, validation loss = 0.2552, patience counter = 45.
# Epoch 302: training loss = 0.2997, validation loss = 0.2580, patience counter = 46.
# Epoch 303: training loss = 0.3078, validation loss = 0.2560, patience counter = 47.
# Epoch 304: training loss = 0.3036, validation loss = 0.2569, patience counter = 48.
# Epoch 305: training loss = 0.3064, validation loss = 0.2589, patience counter = 49.
# Training stopped at epoch 306. Restoring weights from epoch 256.
