# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import torch
from sklearn.preprocessing import StandardScaler

# %%
dict_params = {'data': {'len_input': 100, 'horizon_forecast': 20, 'size_train': 0.8, 'size_valid': 0.2},
               'model': {'n_comp_trend': 3, 'n_neur_hidden': 100, 'frac_dropout': 0.2},
               'training': {'batch_size': 128, 'n_epochs': 500, 'patience': 50, 'min_delta_loss_perc': 0.01}}

# %%
class Block(torch.nn.Module):
    def __init__(self, dict_params: dict, component: str, num_features: int) -> None:
        '''
        Block of the N-BEATS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            component: String representing the component to be modelled; it can be either 'trend' or 'seasonality'.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        #
        len_input = dict_params['data']['len_input']
        horizon_forecast = dict_params['data']['horizon_forecast']
        n_comp_trend = dict_params['model']['n_comp_trend']
        n_neur_hidden = dict_params['model']['n_neur_hidden']
        frac_dropout = dict_params['model']['frac_dropout']
        self.component = component
        self.horizon_forecast = horizon_forecast
        self.n_comp_trend = n_comp_trend
        # hidden layers of the FC stack
        self.dense_hid_1 = torch.nn.Linear(in_features = len_input*num_features, out_features = n_neur_hidden)
        self.dense_hid_2 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.dense_hid_3 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.dense_hid_4 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.relu = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p = frac_dropout)
        self.batch_norm_1 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_2 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_3 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_4 = torch.nn.BatchNorm1d(n_neur_hidden)
        # dense layer for producing the theta's
        self.dense_theta_b = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden, bias = False)
        if component == 'trend':
            self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = self.n_comp_trend + 1, bias = False)
        if component == 'seasonality':
            self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = 2*int(np.floor(horizon_forecast/2-1)) + 1, bias = False)
        # trend and seasonality matrices
        self.mat_T = np.hstack([(np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast)**p for p in range(n_comp_trend+1)]).astype(np.float32)
        self.mat_S = np.hstack([np.arange(horizon_forecast).reshape(-1, 1)**0] +
                               [np.cos(2*np.pi*i*np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast) for i in
                                range(1, int(np.floor(horizon_forecast/2-1)) + 1)] +
                               [np.sin(2*np.pi*i*np.arange(horizon_forecast).reshape(-1, 1)/horizon_forecast) for i in
                                range(1, int(np.floor(horizon_forecast/2-1)) + 1)]).astype(np.float32)
        self.mat_T, self.mat_S = torch.tensor(self.mat_T), torch.tensor(self.mat_S)
        # final layer for backcasting
        self.dense_x_hat = torch.nn.Linear(in_features = n_neur_hidden, out_features = len_input)
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        #
        y = self.dense_hid_1(x)
        y = self.batch_norm_1(y)
        y = self.relu(y)
        y = self.dropout(y)
        for i in range(3):
            hidden_layer = [self.dense_hid_2, self.dense_hid_3, self.dense_hid_4][i]
            batch_norm = [self.batch_norm_2, self.batch_norm_3, self.batch_norm_4][i]
            y = hidden_layer(y)
            y = batch_norm(y)
            y = self.relu(y)
            y = self.dropout(y)
        # compute theta's
        theta_b = self.dense_theta_b(y)
        theta_f = self.dense_theta_f(y)
        # compute backcast
        x_hat = self.dense_x_hat(theta_b)
        x_hat = x_hat.reshape(*x_hat.shape, 1)
        # compute time series components
        if self.component == 'trend':
            y_hat = torch.matmul(self.mat_T.repeat(theta_f.shape[0], 1, 1), theta_f.reshape(*theta_f.shape, 1))
        if self.component == 'seasonality':
            y_hat = torch.matmul(self.mat_S.repeat(theta_f.shape[0], 1, 1), theta_f.reshape(*theta_f.shape, 1))
        #
        return x_hat, y_hat

class Stack(torch.nn.Module):
    def __init__(self, dict_params: dict, component: str, num_features: int) -> None:
        '''
        Stack of the N-BEATS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            component: String representing the component to be modelled; it can be either 'trend' or 'seasonality'.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        #
        self.block_1 = Block(dict_params = dict_params, component = component, num_features = num_features)
        self.block_2 = Block(dict_params = dict_params, component = component, num_features = num_features)
        self.block_3 = Block(dict_params = dict_params, component = component, num_features = num_features)
        
    def forward(self, x):
        # first block
        x_hat, y = self.block_1(x)
        x = x - x_hat
        y_hat = y
        # second block
        x_hat, y = self.block_2(x)
        x = x - x_hat
        y_hat += y
        # third block
        x_hat, y = self.block_3(x)
        x = x - x_hat
        y_hat += y
        #
        x_hat = x
        return x_hat, y_hat

class NBeats(torch.nn.Module):
    def __init__(self, dict_params: dict, num_features: int) -> None:
        '''
        N-BEATS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        #
        self.stack_trend = Stack(dict_params = dict_params, component = 'trend', num_features = num_features)
        self.stack_seas = Stack(dict_params = dict_params, component = 'seasonality', num_features = num_features)
        
    def forward(self, x):
        # trend stack
        x_hat, y_hat_trend = self.stack_trend(x)
        x = x - x_hat
        # seasonality stack
        _, y_hat_seas = self.stack_seas(x)
        #
        return y_hat_trend, y_hat_seas

# %%
def train_test_splitting(df: pd.DataFrame, dict_params: dict) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame):
    '''
    Function to split data in training, validation and test set.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        dict_params: Dictionary containing information about the model architecture.

    Returns:
        df_train: Dataframe corresponding to training set.
        df_valid: Dataframe corresponding to validation set.
        df_test: Dataframe corresponding to test set.
    '''
    df_train = df.iloc[:int(df.shape[0]*dict_params['data']['size_train'])].copy().reset_index(drop = True)
    df_test = df.iloc[int(df.shape[0]*dict_params['data']['size_train']):].reset_index(drop = True).copy().reset_index(drop = True)
    df_valid = df_train.iloc[int(df_train.shape[0]*(1 - dict_params['data']['size_valid'])):].copy().reset_index(drop = True)
    df_train = df_train.iloc[:int(df_train.shape[0]*(1 - dict_params['data']['size_valid']))].copy().reset_index(drop = True)
    # rescale data
    scaler = StandardScaler().fit(df_train[['y']])
    df_train[['y']] = scaler.transform(df_train[['y']])
    df_valid[['y']] = scaler.transform(df_valid[['y']])
    df_test[['y']] = scaler.transform(df_test[['y']])
    #
    return df_train, df_valid, df_test, scaler

# %%
def get_x_y(df: pd.DataFrame, df_future: pd.DataFrame, dict_params: dict, test_set: bool = False,
            horizon_forecast: int = None) -> (torch.tensor, torch.tensor, np.array, np.array):
    '''
    Function obtain a tensor of regressors and one of target series.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        df_future: Same as `df`, but corresponding to its future (e.g., `df_valid` could be the "future" of `df_train`).
        dict_params: Dictionary containing information about the model architecture.
        test_set: Whether `df` is the dataframe corresponding to test set.
        horizon_forecast: Length of the series to be predicted.

    Returns:
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_x: Array containing the dates corresponding to the elements of `x`.
        date_y: Array containing the dates corresponding to the elements of `y`.
    '''
    dict_params = dict_params['data']
    #
    len_input = dict_params['len_input']
    if (horizon_forecast is None) or (horizon_forecast >= len_input):
        horizon_forecast = len_input
    #
    df_present = df.copy()
    if test_set == False:
        df_future = pd.concat((df_present, df_future)).copy().shift(-len_input)
        df_future = df_future.iloc[:df_present.shape[0]].reset_index(drop = True)
    else:
        df_future = df_present.copy().shift(-len_input).dropna()
        df_present = df_present.iloc[:df_future.shape[0]]
    #
    x = np.array([df_present.loc[i: i + len_input - 1,
                                 [col for col in df_present.columns if col != 'date']].values for i in range(df_present.shape[0] - len_input)])
    y = np.array([df_future.loc[i: i + horizon_forecast - 1, ['y']].values for i in range(df_future.shape[0] - horizon_forecast)])
    date_x = np.array([df_present.loc[i: i + len_input - 1, 'date'].values for i in range(df_present.shape[0] - len_input)])
    date_y = np.array([df_future.loc[i: i + horizon_forecast - 1, 'date'].values for i in range(df_future.shape[0] - horizon_forecast)])
    #
    y = y[:x.shape[0]]
    date_y = date_y[:date_x.shape[0]]
    #
    x = torch.tensor(x.astype(np.float32))
    y = torch.tensor(y.astype(np.float32))
    #
    date_x = date_x.reshape(x.shape[0], -1, 1)
    date_y = date_y.reshape(y.shape[0], -1, 1)
    #
    return x, y, date_x, date_y

# %%
class CreateDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        '''
        Class to create a PyTorch dataset.
        
        Args:
            x: Tensor representing regressors.
            y: Tensor representing target time series.
            
        Returns: None.
        '''
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.x.shape[0]
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
class TrainNBeats:
    def __init__(self, model: torch.nn.Module, dict_params: dict, dataloader_train: torch.utils.data.DataLoader, dataloader_valid: torch.utils.data.DataLoader):
        '''
        Class to train the N-BEATS model.
        
        Args:
            model: PyTorch model.
            dict_params: Dictionary containing information about the model architecture.
            dataloader_train: Dataloader containing training data.
            dataloader_valid: Dataloader containing validation data.
            
        Returns: None.
        '''
        self.model = model
        self.dict_params = dict_params
        self.loss_func = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(params = model.parameters())
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer = self.optimizer, factor = 0.5)
        self.dataloader_train = dataloader_train
        self.dataloader_valid = dataloader_valid

    def _model_on_batch(self, batch: tuple, training: bool, loss_epoch: float) -> float:
        '''
        Function to perform training on a single batch of data.
        
        Args:
            batch: Batch of data to use for training/evaluation.
            training: Whether to perform training (if not, evaluation is understood).
            loss_epoch: Loss of the current epoch.
            
        Returns:
            loss: Value of the loss function.
        '''
        if training == True:
            self.optimizer.zero_grad()
        #
        x, y_true = batch
        x = x.to('cpu')
        y_true = y_true.to('cpu')
        y_hat_trend, y_hat_seas = self.model(x)
        y_hat_trend = y_hat_trend.to('cpu')
        y_hat_seas = y_hat_seas.to('cpu')
        #
        loss = self.loss_func(y_hat_trend + y_hat_seas, y_true)
        #
        if training == True:
            loss.backward()
            self.optimizer.step()
        #
        return loss.item()

    def _train(self) -> float:
        '''
        Function to train the N-BEATS model on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the training loss function per batch.
        '''
        self.model.train()
        loss_epoch = 0
        for batch in self.dataloader_train:
            loss_epoch += self._model_on_batch(batch = batch, training = True, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_train)

    def _eval(self) -> float:
        '''
        Function to evaluate the N-BEATS model on the validation set on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the validation loss function per batch.
        '''
        self.model.eval()
        loss_epoch = 0
        with torch.no_grad():
            for batch in self.dataloader_valid:
                loss_epoch += self._model_on_batch(batch = batch, training = False, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_valid)

    def train_model(self) -> (torch.nn.Module, list, list):
        '''
        Function to train the N-BEATS model.
        
        Args: None.
            
        Returns:
            model: Trained N-BEATS model.
            list_loss_train: List of training loss function across the epochs.
            list_loss_valid: List of validation loss function across the epochs.
        '''
        dict_params = self.dict_params
        n_epochs = dict_params['training']['n_epochs']
        list_loss_train, list_loss_valid = [], []
        counter_patience = 0
        for epoch in range(1, n_epochs + 1):
            loss_train = self._train()
            loss_valid = self._eval()
            #
            if (len(list_loss_valid) > 0) and (loss_valid >= np.min(list_loss_valid)*(1 - dict_params['training']['min_delta_loss_perc'])):
                counter_patience += 1
            if (len(list_loss_valid) == 0) or ((len(list_loss_valid) > 0) and (loss_valid < np.min(list_loss_valid))):
                counter_patience = 0
                torch.save(self.model.state_dict(), '../data/artifacts/weights.p')
            if counter_patience >= dict_params['training']['patience']:
                print(f'Training stopped at epoch {epoch}. Restoring weights from epoch {np.argmin(list_loss_valid) + 1}.')
                self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
                break
            #
            print(f'Epoch {epoch}: training loss = {loss_train:.4f}, validation loss = {loss_valid:.4f}, patience counter = {counter_patience}.')
            self.scheduler.step(loss_valid)
            #
            list_loss_train.append(loss_train)
            list_loss_valid.append(loss_valid)
        if epoch == n_epochs:
            self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
        return self.model, list_loss_train, list_loss_valid

# %%
def get_y_true_y_hat(model: torch.nn.Module, x: torch.tensor, y: torch.tensor, date_y: np.array,
                     scaler: sklearn.preprocessing.StandardScaler) -> (np.array, np.array, np.array):
    '''
    Function to get the real time series and its prediction.
    
    Args:
        model: Trained N-BEATS model.
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_y: Array containing the dates corresponding to the elements of `y`.
        scaler: Scaled used to rescale data.
        
    Returns:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
    '''
    list_date = []
    y_true = []
    y_hat_trend, y_hat_seas = [], []
    pred_trend, pred_seas = model(x)
    for i in range(np.unique(date_y).shape[0]):
        date = np.unique(date_y)[i]
        list_date.append(date)
        idx = np.where(date_y == date)
        y_true.append(y.numpy()[idx].mean())
        y_hat_trend.append(pred_trend.detach().numpy()[idx].mean())
        y_hat_seas.append(pred_seas.detach().numpy()[idx].mean())
    y_true = np.array(y_true)
    y_hat_trend = np.array(y_hat_trend)
    y_hat_seas = np.array(y_hat_seas)
    # scale back
    y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).ravel()
    y_hat_trend = scaler.inverse_transform(y_hat_trend.reshape(-1, 1)).ravel()
    y_hat_seas = scaler.inverse_transform(y_hat_seas.reshape(-1, 1)).ravel()
    #
    return y_true, y_hat_trend, y_hat_seas

# %%
def compute_mape(y_true: np.array, y_hat_trend: np.array, y_hat_seas: np.array, scaler: sklearn.preprocessing.StandardScaler) -> float:
    '''
    Function to compute the MAPE.
    
    Args:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
        scaler: Scaled used to rescale data.
        
    Returns:
        mape: MAPE computed from `y_true` and `y_hat`.
    '''
    y_hat = y_hat_trend + y_hat_seas - scaler.mean_
    mape = np.mean(abs(y_true[y_true > 0] - y_hat[y_true > 0])/y_true[y_true > 0])
    return mape

# %%
df = pd.read_csv('../data/raw/train.csv', parse_dates = ['date'], index_col = 'id')
df = df.groupby(['date', 'family']).agg({'sales': 'sum'}).reset_index()
# add all dates
df_temp = []
for family in df['family'].unique():
    df_temp.append(pd.DataFrame({'date': pd.date_range(df['date'].min(), df['date'].max())}).merge(df[df['family'] == family],
                                                                                                on = 'date', how = 'left'))
    df_temp[-1]['family'] = family
    df_temp[-1]['sales'] = df_temp[-1]['sales'].ffill()
df = pd.concat(df_temp).reset_index(drop = True)
del df_temp
df = df.rename(columns = {'sales': 'y'})
# perform train-test splitting
df_train, df_valid, df_test, scaler = train_test_splitting(df = df[df['family'] == 'AUTOMOTIVE'].reset_index(drop = True).drop('family', axis = 1),
                                                        dict_params = dict_params)
#
horizon_forecast = dict_params['data']['horizon_forecast']
# training set data
x_train, y_train, date_x_train, date_y_train = get_x_y(df = df_train, df_future = df_valid, dict_params = dict_params,
                                                    test_set = False, horizon_forecast = horizon_forecast)
# validation set data
x_valid, y_valid, date_x_valid, date_y_valid = get_x_y(df = df_valid, df_future = df_test, dict_params = dict_params,
                                                    test_set = False, horizon_forecast = horizon_forecast)
# test set data
x_test, y_test, date_x_test, date_y_test = get_x_y(df = df_test, df_future = None, dict_params = dict_params, test_set = True,
                                                horizon_forecast = horizon_forecast)
# create datasets and dataloader
dataset_train = CreateDataset(x = x_train, y = y_train)
dataset_valid = CreateDataset(x = x_valid, y = y_valid)
dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size = dict_params['training']['batch_size'], shuffle = True)
dataloader_valid = torch.utils.data.DataLoader(dataset_valid, batch_size = dict_params['training']['batch_size'], shuffle = False)
# train model
model = NBeats(dict_params = dict_params, num_features = x_train.shape[2])
model, list_loss_train, list_loss_valid = TrainNBeats(model = model, dict_params = dict_params, dataloader_train = dataloader_train, dataloader_valid = dataloader_train).train_model()
# evaluate results
model = NBeats(dict_params = dict_params, num_features = x_train.shape[2])
model.load_state_dict(torch.load('../data/artifacts/weights.p'))
model.eval()
# get time series and the corresponding predictions
y_true_train, y_hat_trend_train, y_hat_seas_train = get_y_true_y_hat(model = model, x = x_train, y = y_train, date_y = date_y_train, scaler = scaler)
y_true_valid, y_hat_trend_valid, y_hat_seas_valid = get_y_true_y_hat(model = model, x = x_valid, y = y_valid, date_y = date_y_valid, scaler = scaler)
y_true_test, y_hat_trend_test, y_hat_seas_test = get_y_true_y_hat(model = model, x = x_test, y = y_test, date_y = date_y_test, scaler = scaler)
# compute mape on training, validation and test set
mape_train = compute_mape(y_true = y_true_train, y_hat_trend = y_hat_trend_train, y_hat_seas = y_hat_seas_train, scaler = scaler)
mape_valid = compute_mape(y_true = y_true_valid, y_hat_trend = y_hat_trend_valid, y_hat_seas = y_hat_seas_valid, scaler = scaler)
mape_test = compute_mape(y_true = y_true_test, y_hat_trend = y_hat_trend_test, y_hat_seas = y_hat_seas_test, scaler = scaler)
#
plt.figure(figsize = [10, 6])
plt.plot(np.unique(date_y_test), y_true_test, label = 'True', color = 'r')
plt.plot(np.unique(date_y_test), y_hat_trend_test + y_hat_seas_test - scaler.mean_, label = 'Predicted', color = 'b')
plt.plot(np.unique(date_y_test), y_hat_trend_test, label = 'Trend', color = 'b', ls = '--')
plt.plot(np.unique(date_y_test), y_hat_seas_test - scaler.mean_, label = 'Seasonality', color = 'b', ls = ':')
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.xticks(rotation = 45)
plt.legend()
plt.savefig('../docs/figures_for_readme/result', bbox_inches = 'tight')
plt.show()
#
plt.figure(figsize = [10, 6])
plt.plot(list_loss_train, c = 'r', label = 'Training')
plt.plot(list_loss_valid, c = 'b', label = 'Validation')
plt.xlabel('Epoch', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)
plt.legend()
plt.savefig('../docs/figures_for_readme/loss', bbox_inches = 'tight')
plt.show()
# Out:
# Epoch 1: training loss = 6.1812, validation loss = 1.0911, patience counter = 0.
# Epoch 2: training loss = 4.7157, validation loss = 1.1428, patience counter = 1.
# Epoch 3: training loss = 3.7476, validation loss = 1.0725, patience counter = 0.
# Epoch 4: training loss = 3.2054, validation loss = 0.9730, patience counter = 0.
# Epoch 5: training loss = 2.6063, validation loss = 0.8167, patience counter = 0.
# Epoch 6: training loss = 2.3138, validation loss = 0.7759, patience counter = 0.
# Epoch 7: training loss = 2.0707, validation loss = 0.6736, patience counter = 0.
# Epoch 8: training loss = 1.8347, validation loss = 0.6552, patience counter = 0.
# Epoch 9: training loss = 1.6902, validation loss = 0.6517, patience counter = 0.
# Epoch 10: training loss = 1.4793, validation loss = 0.5442, patience counter = 0.
# Epoch 11: training loss = 1.3641, validation loss = 0.5183, patience counter = 0.
# Epoch 12: training loss = 1.3172, validation loss = 0.4709, patience counter = 0.
# Epoch 13: training loss = 1.1634, validation loss = 0.4724, patience counter = 1.
# Epoch 14: training loss = 1.0822, validation loss = 0.4340, patience counter = 0.
# Epoch 15: training loss = 1.0367, validation loss = 0.4382, patience counter = 1.
# Epoch 16: training loss = 0.9723, validation loss = 0.4267, patience counter = 0.
# Epoch 17: training loss = 0.9288, validation loss = 0.4066, patience counter = 0.
# Epoch 18: training loss = 0.8772, validation loss = 0.4096, patience counter = 1.
# Epoch 19: training loss = 0.8604, validation loss = 0.3867, patience counter = 0.
# Epoch 20: training loss = 0.8070, validation loss = 0.3841, patience counter = 0.
# Epoch 21: training loss = 0.8183, validation loss = 0.3806, patience counter = 0.
# Epoch 22: training loss = 0.7683, validation loss = 0.3708, patience counter = 0.
# Epoch 23: training loss = 0.7269, validation loss = 0.3626, patience counter = 0.
# Epoch 24: training loss = 0.7028, validation loss = 0.3663, patience counter = 1.
# Epoch 25: training loss = 0.7032, validation loss = 0.3550, patience counter = 0.
# Epoch 26: training loss = 0.6753, validation loss = 0.3564, patience counter = 1.
# Epoch 27: training loss = 0.6627, validation loss = 0.3467, patience counter = 0.
# Epoch 28: training loss = 0.6427, validation loss = 0.3453, patience counter = 0.
# Epoch 29: training loss = 0.6556, validation loss = 0.3574, patience counter = 1.
# Epoch 30: training loss = 0.6040, validation loss = 0.3407, patience counter = 0.
# Epoch 31: training loss = 0.6242, validation loss = 0.3372, patience counter = 0.
# Epoch 32: training loss = 0.6209, validation loss = 0.3557, patience counter = 1.
# Epoch 33: training loss = 0.5825, validation loss = 0.3389, patience counter = 2.
# Epoch 34: training loss = 0.5728, validation loss = 0.3269, patience counter = 0.
# Epoch 35: training loss = 0.5733, validation loss = 0.3565, patience counter = 1.
# Epoch 36: training loss = 0.5512, validation loss = 0.3246, patience counter = 0.
# Epoch 37: training loss = 0.5681, validation loss = 0.3354, patience counter = 1.
# Epoch 38: training loss = 0.5381, validation loss = 0.3244, patience counter = 0.
# Epoch 39: training loss = 0.5248, validation loss = 0.3235, patience counter = 0.
# Epoch 40: training loss = 0.5204, validation loss = 0.3276, patience counter = 1.
# Epoch 41: training loss = 0.4989, validation loss = 0.3228, patience counter = 0.
# Epoch 42: training loss = 0.5023, validation loss = 0.3157, patience counter = 0.
# Epoch 43: training loss = 0.5035, validation loss = 0.3175, patience counter = 1.
# Epoch 44: training loss = 0.5039, validation loss = 0.3126, patience counter = 0.
# Epoch 45: training loss = 0.5193, validation loss = 0.3099, patience counter = 0.
# Epoch 46: training loss = 0.5034, validation loss = 0.3132, patience counter = 1.
# Epoch 47: training loss = 0.4811, validation loss = 0.3231, patience counter = 2.
# Epoch 48: training loss = 0.4759, validation loss = 0.3070, patience counter = 0.
# Epoch 49: training loss = 0.4826, validation loss = 0.3154, patience counter = 1.
# Epoch 50: training loss = 0.4760, validation loss = 0.3084, patience counter = 2.
# Epoch 51: training loss = 0.4673, validation loss = 0.3025, patience counter = 0.
# Epoch 52: training loss = 0.4844, validation loss = 0.3325, patience counter = 1.
# Epoch 53: training loss = 0.4527, validation loss = 0.3053, patience counter = 2.
# Epoch 54: training loss = 0.4665, validation loss = 0.3039, patience counter = 3.
# Epoch 55: training loss = 0.4637, validation loss = 0.3176, patience counter = 4.
# Epoch 56: training loss = 0.4467, validation loss = 0.3122, patience counter = 5.
# Epoch 57: training loss = 0.4466, validation loss = 0.3006, patience counter = 0.
# Epoch 58: training loss = 0.4578, validation loss = 0.3177, patience counter = 1.
# Epoch 59: training loss = 0.4410, validation loss = 0.2995, patience counter = 0.
# Epoch 60: training loss = 0.4374, validation loss = 0.3021, patience counter = 1.
# Epoch 61: training loss = 0.4215, validation loss = 0.3164, patience counter = 2.
# Epoch 62: training loss = 0.4252, validation loss = 0.3002, patience counter = 3.
# Epoch 63: training loss = 0.4313, validation loss = 0.2992, patience counter = 0.
# Epoch 64: training loss = 0.4261, validation loss = 0.2970, patience counter = 0.
# Epoch 65: training loss = 0.4253, validation loss = 0.3012, patience counter = 1.
# Epoch 66: training loss = 0.4157, validation loss = 0.2973, patience counter = 2.
# Epoch 67: training loss = 0.4159, validation loss = 0.2981, patience counter = 3.
# Epoch 68: training loss = 0.4120, validation loss = 0.2952, patience counter = 0.
# Epoch 69: training loss = 0.4065, validation loss = 0.2947, patience counter = 0.
# Epoch 70: training loss = 0.4039, validation loss = 0.2935, patience counter = 0.
# Epoch 71: training loss = 0.4132, validation loss = 0.2916, patience counter = 0.
# Epoch 72: training loss = 0.4100, validation loss = 0.2947, patience counter = 1.
# Epoch 73: training loss = 0.3996, validation loss = 0.2949, patience counter = 2.
# Epoch 74: training loss = 0.3933, validation loss = 0.2888, patience counter = 0.
# Epoch 75: training loss = 0.3969, validation loss = 0.2974, patience counter = 1.
# Epoch 76: training loss = 0.3929, validation loss = 0.2929, patience counter = 2.
# Epoch 77: training loss = 0.3929, validation loss = 0.2908, patience counter = 3.
# Epoch 78: training loss = 0.3809, validation loss = 0.2902, patience counter = 4.
# Epoch 79: training loss = 0.3869, validation loss = 0.2859, patience counter = 0.
# Epoch 80: training loss = 0.3898, validation loss = 0.2942, patience counter = 1.
# Epoch 81: training loss = 0.3877, validation loss = 0.2910, patience counter = 2.
# Epoch 82: training loss = 0.3902, validation loss = 0.2855, patience counter = 0.
# Epoch 83: training loss = 0.3848, validation loss = 0.2862, patience counter = 1.
# Epoch 84: training loss = 0.3835, validation loss = 0.3003, patience counter = 2.
# Epoch 85: training loss = 0.3730, validation loss = 0.2846, patience counter = 0.
# Epoch 86: training loss = 0.3763, validation loss = 0.2860, patience counter = 1.
# Epoch 87: training loss = 0.3854, validation loss = 0.2868, patience counter = 2.
# Epoch 88: training loss = 0.3714, validation loss = 0.2920, patience counter = 3.
# Epoch 89: training loss = 0.3879, validation loss = 0.2821, patience counter = 0.
# Epoch 90: training loss = 0.3809, validation loss = 0.2838, patience counter = 1.
# Epoch 91: training loss = 0.3766, validation loss = 0.2961, patience counter = 2.
# Epoch 92: training loss = 0.3681, validation loss = 0.2869, patience counter = 3.
# Epoch 93: training loss = 0.3664, validation loss = 0.2845, patience counter = 4.
# Epoch 94: training loss = 0.3754, validation loss = 0.2882, patience counter = 5.
# Epoch 95: training loss = 0.3716, validation loss = 0.2862, patience counter = 6.
# Epoch 96: training loss = 0.3681, validation loss = 0.2863, patience counter = 7.
# Epoch 97: training loss = 0.3616, validation loss = 0.2842, patience counter = 8.
# Epoch 98: training loss = 0.3692, validation loss = 0.2789, patience counter = 0.
# Epoch 99: training loss = 0.3593, validation loss = 0.2797, patience counter = 1.
# Epoch 100: training loss = 0.3623, validation loss = 0.2797, patience counter = 2.
# Epoch 101: training loss = 0.3503, validation loss = 0.2862, patience counter = 3.
# Epoch 102: training loss = 0.3643, validation loss = 0.2785, patience counter = 0.
# Epoch 103: training loss = 0.3544, validation loss = 0.2827, patience counter = 1.
# Epoch 104: training loss = 0.3513, validation loss = 0.2796, patience counter = 2.
# Epoch 105: training loss = 0.3583, validation loss = 0.2762, patience counter = 0.
# Epoch 106: training loss = 0.3502, validation loss = 0.2716, patience counter = 0.
# Epoch 107: training loss = 0.3502, validation loss = 0.2774, patience counter = 1.
# Epoch 108: training loss = 0.3500, validation loss = 0.2770, patience counter = 2.
# Epoch 109: training loss = 0.3435, validation loss = 0.2705, patience counter = 0.
# Epoch 110: training loss = 0.3570, validation loss = 0.2808, patience counter = 1.
# Epoch 111: training loss = 0.3503, validation loss = 0.2754, patience counter = 2.
# Epoch 112: training loss = 0.3504, validation loss = 0.2881, patience counter = 3.
# Epoch 113: training loss = 0.3531, validation loss = 0.2693, patience counter = 0.
# Epoch 114: training loss = 0.3482, validation loss = 0.2781, patience counter = 1.
# Epoch 115: training loss = 0.3411, validation loss = 0.2823, patience counter = 2.
# Epoch 116: training loss = 0.3500, validation loss = 0.2718, patience counter = 3.
# Epoch 117: training loss = 0.3517, validation loss = 0.2765, patience counter = 4.
# Epoch 118: training loss = 0.3456, validation loss = 0.2750, patience counter = 5.
# Epoch 119: training loss = 0.3501, validation loss = 0.2716, patience counter = 6.
# Epoch 120: training loss = 0.3487, validation loss = 0.2893, patience counter = 7.
# Epoch 121: training loss = 0.3547, validation loss = 0.2681, patience counter = 0.
# Epoch 122: training loss = 0.3413, validation loss = 0.2667, patience counter = 0.
# Epoch 123: training loss = 0.3384, validation loss = 0.2809, patience counter = 1.
# Epoch 124: training loss = 0.3404, validation loss = 0.2705, patience counter = 2.
# Epoch 125: training loss = 0.3460, validation loss = 0.2750, patience counter = 3.
# Epoch 126: training loss = 0.3357, validation loss = 0.2723, patience counter = 4.
# Epoch 127: training loss = 0.3408, validation loss = 0.2679, patience counter = 5.
# Epoch 128: training loss = 0.3313, validation loss = 0.2707, patience counter = 6.
# Epoch 129: training loss = 0.3312, validation loss = 0.2664, patience counter = 0.
# Epoch 130: training loss = 0.3330, validation loss = 0.2650, patience counter = 0.
# Epoch 131: training loss = 0.3347, validation loss = 0.2674, patience counter = 1.
# Epoch 132: training loss = 0.3294, validation loss = 0.2639, patience counter = 0.
# Epoch 133: training loss = 0.3344, validation loss = 0.2641, patience counter = 1.
# Epoch 134: training loss = 0.3322, validation loss = 0.2644, patience counter = 2.
# Epoch 135: training loss = 0.3337, validation loss = 0.2672, patience counter = 3.
# Epoch 136: training loss = 0.3299, validation loss = 0.2678, patience counter = 4.
# Epoch 137: training loss = 0.3332, validation loss = 0.2625, patience counter = 0.
# Epoch 138: training loss = 0.3348, validation loss = 0.2696, patience counter = 1.
# Epoch 139: training loss = 0.3333, validation loss = 0.2716, patience counter = 2.
# Epoch 140: training loss = 0.3359, validation loss = 0.2623, patience counter = 0.
# Epoch 141: training loss = 0.3307, validation loss = 0.2617, patience counter = 0.
# Epoch 142: training loss = 0.3324, validation loss = 0.2725, patience counter = 1.
# Epoch 143: training loss = 0.3410, validation loss = 0.2731, patience counter = 2.
# Epoch 144: training loss = 0.3357, validation loss = 0.2642, patience counter = 3.
# Epoch 145: training loss = 0.3315, validation loss = 0.2587, patience counter = 0.
# Epoch 146: training loss = 0.3275, validation loss = 0.2617, patience counter = 1.
# Epoch 147: training loss = 0.3333, validation loss = 0.2669, patience counter = 2.
# Epoch 148: training loss = 0.3232, validation loss = 0.2577, patience counter = 0.
# Epoch 149: training loss = 0.3275, validation loss = 0.2564, patience counter = 0.
# Epoch 150: training loss = 0.3342, validation loss = 0.2866, patience counter = 1.
# Epoch 151: training loss = 0.3277, validation loss = 0.2543, patience counter = 0.
# Epoch 152: training loss = 0.3344, validation loss = 0.2554, patience counter = 1.
# Epoch 153: training loss = 0.3335, validation loss = 0.2705, patience counter = 2.
# Epoch 154: training loss = 0.3298, validation loss = 0.2597, patience counter = 3.
# Epoch 155: training loss = 0.3229, validation loss = 0.2637, patience counter = 4.
# Epoch 156: training loss = 0.3239, validation loss = 0.2529, patience counter = 0.
# Epoch 157: training loss = 0.3174, validation loss = 0.2566, patience counter = 1.
# Epoch 158: training loss = 0.3164, validation loss = 0.2591, patience counter = 2.
# Epoch 159: training loss = 0.3160, validation loss = 0.2562, patience counter = 3.
# Epoch 160: training loss = 0.3220, validation loss = 0.2530, patience counter = 4.
# Epoch 161: training loss = 0.3274, validation loss = 0.2540, patience counter = 5.
# Epoch 162: training loss = 0.3178, validation loss = 0.2706, patience counter = 6.
# Epoch 163: training loss = 0.3196, validation loss = 0.2554, patience counter = 7.
# Epoch 164: training loss = 0.3281, validation loss = 0.2525, patience counter = 0.
# Epoch 165: training loss = 0.3192, validation loss = 0.2536, patience counter = 1.
# Epoch 166: training loss = 0.3144, validation loss = 0.2540, patience counter = 2.
# Epoch 167: training loss = 0.3107, validation loss = 0.2536, patience counter = 3.
# Epoch 168: training loss = 0.3192, validation loss = 0.2526, patience counter = 4.
# Epoch 169: training loss = 0.3278, validation loss = 0.2540, patience counter = 5.
# Epoch 170: training loss = 0.3240, validation loss = 0.2610, patience counter = 6.
# Epoch 171: training loss = 0.3158, validation loss = 0.2534, patience counter = 7.
# Epoch 172: training loss = 0.3114, validation loss = 0.2520, patience counter = 0.
# Epoch 173: training loss = 0.3099, validation loss = 0.2501, patience counter = 0.
# Epoch 174: training loss = 0.3081, validation loss = 0.2492, patience counter = 0.
# Epoch 175: training loss = 0.3153, validation loss = 0.2526, patience counter = 1.
# Epoch 176: training loss = 0.3167, validation loss = 0.2466, patience counter = 0.
# Epoch 177: training loss = 0.3094, validation loss = 0.2492, patience counter = 1.
# Epoch 178: training loss = 0.3071, validation loss = 0.2531, patience counter = 2.
# Epoch 179: training loss = 0.3116, validation loss = 0.2448, patience counter = 0.
# Epoch 180: training loss = 0.3131, validation loss = 0.2535, patience counter = 1.
# Epoch 181: training loss = 0.3077, validation loss = 0.2516, patience counter = 2.
# Epoch 182: training loss = 0.3086, validation loss = 0.2472, patience counter = 3.
# Epoch 183: training loss = 0.3156, validation loss = 0.2475, patience counter = 4.
# Epoch 184: training loss = 0.3128, validation loss = 0.2521, patience counter = 5.
# Epoch 185: training loss = 0.3086, validation loss = 0.2519, patience counter = 6.
# Epoch 186: training loss = 0.3013, validation loss = 0.2471, patience counter = 7.
# Epoch 187: training loss = 0.3100, validation loss = 0.2482, patience counter = 8.
# Epoch 188: training loss = 0.3092, validation loss = 0.2456, patience counter = 9.
# Epoch 189: training loss = 0.3056, validation loss = 0.2441, patience counter = 0.
# Epoch 190: training loss = 0.3118, validation loss = 0.2489, patience counter = 1.
# Epoch 191: training loss = 0.3058, validation loss = 0.2483, patience counter = 2.
# Epoch 192: training loss = 0.3138, validation loss = 0.2435, patience counter = 0.
# Epoch 193: training loss = 0.3073, validation loss = 0.2510, patience counter = 1.
# Epoch 194: training loss = 0.3142, validation loss = 0.2489, patience counter = 2.
# Epoch 195: training loss = 0.2978, validation loss = 0.2483, patience counter = 3.
# Epoch 196: training loss = 0.3009, validation loss = 0.2414, patience counter = 0.
# Epoch 197: training loss = 0.3002, validation loss = 0.2414, patience counter = 1.
# Epoch 198: training loss = 0.2995, validation loss = 0.2401, patience counter = 0.
# Epoch 199: training loss = 0.3026, validation loss = 0.2406, patience counter = 1.
# Epoch 200: training loss = 0.3006, validation loss = 0.2397, patience counter = 0.
# Epoch 201: training loss = 0.3026, validation loss = 0.2466, patience counter = 1.
# Epoch 202: training loss = 0.3004, validation loss = 0.2446, patience counter = 2.
# Epoch 203: training loss = 0.2957, validation loss = 0.2403, patience counter = 3.
# Epoch 204: training loss = 0.3008, validation loss = 0.2459, patience counter = 4.
# Epoch 205: training loss = 0.2976, validation loss = 0.2371, patience counter = 0.
# Epoch 206: training loss = 0.2987, validation loss = 0.2497, patience counter = 1.
# Epoch 207: training loss = 0.2959, validation loss = 0.2386, patience counter = 2.
# Epoch 208: training loss = 0.2961, validation loss = 0.2357, patience counter = 0.
# Epoch 209: training loss = 0.2990, validation loss = 0.2451, patience counter = 1.
# Epoch 210: training loss = 0.2975, validation loss = 0.2372, patience counter = 2.
# Epoch 211: training loss = 0.2945, validation loss = 0.2336, patience counter = 0.
# Epoch 212: training loss = 0.3087, validation loss = 0.2418, patience counter = 1.
# Epoch 213: training loss = 0.3002, validation loss = 0.2644, patience counter = 2.
# Epoch 214: training loss = 0.3019, validation loss = 0.2361, patience counter = 3.
# Epoch 215: training loss = 0.3023, validation loss = 0.2411, patience counter = 4.
# Epoch 216: training loss = 0.2965, validation loss = 0.2427, patience counter = 5.
# Epoch 217: training loss = 0.2949, validation loss = 0.2336, patience counter = 6.
# Epoch 218: training loss = 0.2970, validation loss = 0.2351, patience counter = 7.
# Epoch 219: training loss = 0.3094, validation loss = 0.2339, patience counter = 8.
# Epoch 220: training loss = 0.3154, validation loss = 0.2431, patience counter = 9.
# Epoch 221: training loss = 0.2967, validation loss = 0.2470, patience counter = 10.
# Epoch 222: training loss = 0.2935, validation loss = 0.2304, patience counter = 0.
# Epoch 223: training loss = 0.2963, validation loss = 0.2347, patience counter = 1.
# Epoch 224: training loss = 0.3007, validation loss = 0.2478, patience counter = 2.
# Epoch 225: training loss = 0.2918, validation loss = 0.2339, patience counter = 3.
# Epoch 226: training loss = 0.2921, validation loss = 0.2298, patience counter = 0.
# Epoch 227: training loss = 0.2906, validation loss = 0.2371, patience counter = 1.
# Epoch 228: training loss = 0.2915, validation loss = 0.2462, patience counter = 2.
# Epoch 229: training loss = 0.2946, validation loss = 0.2302, patience counter = 3.
# Epoch 230: training loss = 0.2894, validation loss = 0.2349, patience counter = 4.
# Epoch 231: training loss = 0.2930, validation loss = 0.2284, patience counter = 0.
# Epoch 232: training loss = 0.2875, validation loss = 0.2338, patience counter = 1.
# Epoch 233: training loss = 0.2927, validation loss = 0.2415, patience counter = 2.
# Epoch 234: training loss = 0.2833, validation loss = 0.2271, patience counter = 0.
# Epoch 235: training loss = 0.2884, validation loss = 0.2278, patience counter = 1.
# Epoch 236: training loss = 0.2901, validation loss = 0.2342, patience counter = 2.
# Epoch 237: training loss = 0.2897, validation loss = 0.2314, patience counter = 3.
# Epoch 238: training loss = 0.2841, validation loss = 0.2277, patience counter = 4.
# Epoch 239: training loss = 0.2879, validation loss = 0.2260, patience counter = 0.
# Epoch 240: training loss = 0.2827, validation loss = 0.2451, patience counter = 1.
# Epoch 241: training loss = 0.2877, validation loss = 0.2297, patience counter = 2.
# Epoch 242: training loss = 0.2888, validation loss = 0.2301, patience counter = 3.
# Epoch 243: training loss = 0.2834, validation loss = 0.2253, patience counter = 0.
# Epoch 244: training loss = 0.2875, validation loss = 0.2332, patience counter = 1.
# Epoch 245: training loss = 0.2865, validation loss = 0.2277, patience counter = 2.
# Epoch 246: training loss = 0.2844, validation loss = 0.2277, patience counter = 3.
# Epoch 247: training loss = 0.2865, validation loss = 0.2268, patience counter = 4.
# Epoch 248: training loss = 0.2752, validation loss = 0.2263, patience counter = 5.
# Epoch 249: training loss = 0.2774, validation loss = 0.2233, patience counter = 0.
# Epoch 250: training loss = 0.2797, validation loss = 0.2237, patience counter = 1.
# Epoch 251: training loss = 0.2843, validation loss = 0.2242, patience counter = 2.
# Epoch 252: training loss = 0.2846, validation loss = 0.2233, patience counter = 3.
# Epoch 253: training loss = 0.2843, validation loss = 0.2307, patience counter = 4.
# Epoch 254: training loss = 0.2798, validation loss = 0.2289, patience counter = 5.
# Epoch 255: training loss = 0.2882, validation loss = 0.2249, patience counter = 6.
# Epoch 256: training loss = 0.2887, validation loss = 0.2228, patience counter = 0.
# Epoch 257: training loss = 0.2854, validation loss = 0.2208, patience counter = 0.
# Epoch 258: training loss = 0.2868, validation loss = 0.2332, patience counter = 1.
# Epoch 259: training loss = 0.2820, validation loss = 0.2333, patience counter = 2.
# Epoch 260: training loss = 0.2790, validation loss = 0.2204, patience counter = 0.
# Epoch 261: training loss = 0.2850, validation loss = 0.2314, patience counter = 1.
# Epoch 262: training loss = 0.2770, validation loss = 0.2250, patience counter = 2.
# Epoch 263: training loss = 0.2775, validation loss = 0.2252, patience counter = 3.
# Epoch 264: training loss = 0.2760, validation loss = 0.2270, patience counter = 4.
# Epoch 265: training loss = 0.2908, validation loss = 0.2229, patience counter = 5.
# Epoch 266: training loss = 0.2758, validation loss = 0.2194, patience counter = 0.
# Epoch 267: training loss = 0.2763, validation loss = 0.2216, patience counter = 1.
# Epoch 268: training loss = 0.2743, validation loss = 0.2172, patience counter = 0.
# Epoch 269: training loss = 0.2755, validation loss = 0.2235, patience counter = 1.
# Epoch 270: training loss = 0.2754, validation loss = 0.2175, patience counter = 2.
# Epoch 271: training loss = 0.2791, validation loss = 0.2242, patience counter = 3.
# Epoch 272: training loss = 0.2718, validation loss = 0.2221, patience counter = 4.
# Epoch 273: training loss = 0.2665, validation loss = 0.2213, patience counter = 5.
# Epoch 274: training loss = 0.2741, validation loss = 0.2200, patience counter = 6.
# Epoch 275: training loss = 0.2778, validation loss = 0.2337, patience counter = 7.
# Epoch 276: training loss = 0.2794, validation loss = 0.2185, patience counter = 8.
# Epoch 277: training loss = 0.2825, validation loss = 0.2214, patience counter = 9.
# Epoch 278: training loss = 0.2830, validation loss = 0.2199, patience counter = 10.
# Epoch 279: training loss = 0.2742, validation loss = 0.2191, patience counter = 11.
# Epoch 280: training loss = 0.2734, validation loss = 0.2184, patience counter = 12.
# Epoch 281: training loss = 0.2719, validation loss = 0.2154, patience counter = 0.
# Epoch 282: training loss = 0.2712, validation loss = 0.2153, patience counter = 0.
# Epoch 283: training loss = 0.2665, validation loss = 0.2165, patience counter = 1.
# Epoch 284: training loss = 0.2697, validation loss = 0.2161, patience counter = 2.
# Epoch 285: training loss = 0.2666, validation loss = 0.2188, patience counter = 3.
# Epoch 286: training loss = 0.2627, validation loss = 0.2142, patience counter = 0.
# Epoch 287: training loss = 0.2664, validation loss = 0.2167, patience counter = 1.
# Epoch 288: training loss = 0.2691, validation loss = 0.2164, patience counter = 2.
# Epoch 289: training loss = 0.2740, validation loss = 0.2146, patience counter = 3.
# Epoch 290: training loss = 0.2681, validation loss = 0.2172, patience counter = 4.
# Epoch 291: training loss = 0.2659, validation loss = 0.2145, patience counter = 5.
# Epoch 292: training loss = 0.2691, validation loss = 0.2169, patience counter = 6.
# Epoch 293: training loss = 0.2662, validation loss = 0.2144, patience counter = 7.
# Epoch 294: training loss = 0.2733, validation loss = 0.2145, patience counter = 8.
# Epoch 295: training loss = 0.2662, validation loss = 0.2130, patience counter = 0.
# Epoch 296: training loss = 0.2687, validation loss = 0.2147, patience counter = 1.
# Epoch 297: training loss = 0.2680, validation loss = 0.2169, patience counter = 2.
# Epoch 298: training loss = 0.2626, validation loss = 0.2128, patience counter = 0.
# Epoch 299: training loss = 0.2669, validation loss = 0.2160, patience counter = 1.
# Epoch 300: training loss = 0.2660, validation loss = 0.2103, patience counter = 0.
# Epoch 301: training loss = 0.2667, validation loss = 0.2151, patience counter = 1.
# Epoch 302: training loss = 0.2607, validation loss = 0.2119, patience counter = 2.
# Epoch 303: training loss = 0.2633, validation loss = 0.2168, patience counter = 3.
# Epoch 304: training loss = 0.2693, validation loss = 0.2162, patience counter = 4.
# Epoch 305: training loss = 0.2610, validation loss = 0.2123, patience counter = 5.
# Epoch 306: training loss = 0.2594, validation loss = 0.2161, patience counter = 6.
# Epoch 307: training loss = 0.2628, validation loss = 0.2121, patience counter = 7.
# Epoch 308: training loss = 0.2651, validation loss = 0.2143, patience counter = 8.
# Epoch 309: training loss = 0.2591, validation loss = 0.2109, patience counter = 9.
# Epoch 310: training loss = 0.2620, validation loss = 0.2128, patience counter = 10.
# Epoch 311: training loss = 0.2608, validation loss = 0.2115, patience counter = 11.
# Epoch 312: training loss = 0.2600, validation loss = 0.2123, patience counter = 12.
# Epoch 313: training loss = 0.2613, validation loss = 0.2112, patience counter = 13.
# Epoch 314: training loss = 0.2617, validation loss = 0.2099, patience counter = 0.
# Epoch 315: training loss = 0.2565, validation loss = 0.2095, patience counter = 0.
# Epoch 316: training loss = 0.2584, validation loss = 0.2079, patience counter = 0.
# Epoch 317: training loss = 0.2543, validation loss = 0.2092, patience counter = 1.
# Epoch 318: training loss = 0.2667, validation loss = 0.2118, patience counter = 2.
# Epoch 319: training loss = 0.2613, validation loss = 0.2102, patience counter = 3.
# Epoch 320: training loss = 0.2609, validation loss = 0.2101, patience counter = 4.
# Epoch 321: training loss = 0.2671, validation loss = 0.2148, patience counter = 5.
# Epoch 322: training loss = 0.2592, validation loss = 0.2097, patience counter = 6.
# Epoch 323: training loss = 0.2555, validation loss = 0.2125, patience counter = 7.
# Epoch 324: training loss = 0.2598, validation loss = 0.2097, patience counter = 8.
# Epoch 325: training loss = 0.2615, validation loss = 0.2113, patience counter = 9.
# Epoch 326: training loss = 0.2595, validation loss = 0.2095, patience counter = 10.
# Epoch 327: training loss = 0.2582, validation loss = 0.2113, patience counter = 11.
# Epoch 328: training loss = 0.2578, validation loss = 0.2133, patience counter = 12.
# Epoch 329: training loss = 0.2580, validation loss = 0.2071, patience counter = 0.
# Epoch 330: training loss = 0.2592, validation loss = 0.2094, patience counter = 1.
# Epoch 331: training loss = 0.2543, validation loss = 0.2091, patience counter = 2.
# Epoch 332: training loss = 0.2618, validation loss = 0.2106, patience counter = 3.
# Epoch 333: training loss = 0.2580, validation loss = 0.2081, patience counter = 4.
# Epoch 334: training loss = 0.2545, validation loss = 0.2080, patience counter = 5.
# Epoch 335: training loss = 0.2557, validation loss = 0.2079, patience counter = 6.
# Epoch 336: training loss = 0.2624, validation loss = 0.2093, patience counter = 7.
# Epoch 337: training loss = 0.2540, validation loss = 0.2076, patience counter = 8.
# Epoch 338: training loss = 0.2580, validation loss = 0.2089, patience counter = 9.
# Epoch 339: training loss = 0.2618, validation loss = 0.2111, patience counter = 10.
# Epoch 340: training loss = 0.2594, validation loss = 0.2072, patience counter = 11.
# Epoch 341: training loss = 0.2592, validation loss = 0.2089, patience counter = 12.
# Epoch 342: training loss = 0.2591, validation loss = 0.2100, patience counter = 13.
# Epoch 343: training loss = 0.2541, validation loss = 0.2095, patience counter = 14.
# Epoch 344: training loss = 0.2565, validation loss = 0.2052, patience counter = 0.
# Epoch 345: training loss = 0.2605, validation loss = 0.2078, patience counter = 1.
# Epoch 346: training loss = 0.2558, validation loss = 0.2082, patience counter = 2.
# Epoch 347: training loss = 0.2614, validation loss = 0.2088, patience counter = 3.
# Epoch 348: training loss = 0.2552, validation loss = 0.2085, patience counter = 4.
# Epoch 349: training loss = 0.2541, validation loss = 0.2081, patience counter = 5.
# Epoch 350: training loss = 0.2622, validation loss = 0.2088, patience counter = 6.
# Epoch 351: training loss = 0.2566, validation loss = 0.2087, patience counter = 7.
# Epoch 352: training loss = 0.2583, validation loss = 0.2072, patience counter = 8.
# Epoch 353: training loss = 0.2540, validation loss = 0.2102, patience counter = 9.
# Epoch 354: training loss = 0.2570, validation loss = 0.2092, patience counter = 10.
# Epoch 355: training loss = 0.2594, validation loss = 0.2077, patience counter = 11.
# Epoch 356: training loss = 0.2546, validation loss = 0.2082, patience counter = 12.
# Epoch 357: training loss = 0.2550, validation loss = 0.2080, patience counter = 13.
# Epoch 358: training loss = 0.2519, validation loss = 0.2091, patience counter = 14.
# Epoch 359: training loss = 0.2597, validation loss = 0.2101, patience counter = 15.
# Epoch 360: training loss = 0.2569, validation loss = 0.2093, patience counter = 16.
# Epoch 361: training loss = 0.2579, validation loss = 0.2075, patience counter = 17.
# Epoch 362: training loss = 0.2557, validation loss = 0.2094, patience counter = 18.
# Epoch 363: training loss = 0.2592, validation loss = 0.2095, patience counter = 19.
# Epoch 364: training loss = 0.2531, validation loss = 0.2083, patience counter = 20.
# Epoch 365: training loss = 0.2564, validation loss = 0.2074, patience counter = 21.
# Epoch 366: training loss = 0.2550, validation loss = 0.2069, patience counter = 22.
# Epoch 367: training loss = 0.2521, validation loss = 0.2094, patience counter = 23.
# Epoch 368: training loss = 0.2544, validation loss = 0.2079, patience counter = 24.
# Epoch 369: training loss = 0.2526, validation loss = 0.2082, patience counter = 25.
# Epoch 370: training loss = 0.2560, validation loss = 0.2082, patience counter = 26.
# Epoch 371: training loss = 0.2590, validation loss = 0.2079, patience counter = 27.
# Epoch 372: training loss = 0.2544, validation loss = 0.2071, patience counter = 28.
# Epoch 373: training loss = 0.2532, validation loss = 0.2094, patience counter = 29.
# Epoch 374: training loss = 0.2547, validation loss = 0.2104, patience counter = 30.
# Epoch 375: training loss = 0.2557, validation loss = 0.2070, patience counter = 31.
# Epoch 376: training loss = 0.2547, validation loss = 0.2093, patience counter = 32.
# Epoch 377: training loss = 0.2557, validation loss = 0.2072, patience counter = 33.
# Epoch 378: training loss = 0.2546, validation loss = 0.2054, patience counter = 34.
# Epoch 379: training loss = 0.2552, validation loss = 0.2082, patience counter = 35.
# Epoch 380: training loss = 0.2546, validation loss = 0.2091, patience counter = 36.
# Epoch 381: training loss = 0.2579, validation loss = 0.2091, patience counter = 37.
# Epoch 382: training loss = 0.2542, validation loss = 0.2092, patience counter = 38.
# Epoch 383: training loss = 0.2515, validation loss = 0.2088, patience counter = 39.
# Epoch 384: training loss = 0.2524, validation loss = 0.2081, patience counter = 40.
# Epoch 385: training loss = 0.2517, validation loss = 0.2081, patience counter = 41.
# Epoch 386: training loss = 0.2575, validation loss = 0.2079, patience counter = 42.
# Epoch 387: training loss = 0.2545, validation loss = 0.2080, patience counter = 43.
# Epoch 388: training loss = 0.2530, validation loss = 0.2072, patience counter = 44.
# Epoch 389: training loss = 0.2539, validation loss = 0.2081, patience counter = 45.
# Epoch 390: training loss = 0.2552, validation loss = 0.2101, patience counter = 46.
# Epoch 391: training loss = 0.2617, validation loss = 0.2093, patience counter = 47.
# Epoch 392: training loss = 0.2572, validation loss = 0.2066, patience counter = 48.
# Epoch 393: training loss = 0.2567, validation loss = 0.2059, patience counter = 49.
# Training stopped at epoch 394. Restoring weights from epoch 344.
# C:\Users\alled\AppData\Local\Temp\ipykernel_9316\4283204432.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
# C:\Users\alled\AppData\Local\Temp\ipykernel_9316\1448614060.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('../data/artifacts/weights.p'))
